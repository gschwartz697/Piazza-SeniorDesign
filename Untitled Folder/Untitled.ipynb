# %%
# importing csv module 
import csv 
  
# csv file name 
filename = "contributions.csv"
  
# initializing the titles and rows list 
fields = [] 
rows = [] 
  
# reading csv file 
with open(filename, 'r', encoding="utf8") as csvfile: 
    # creating a csv reader object 
    csvreader = csv.reader(csvfile) 
      
    # extracting field names through first row 
    fields = next(csvreader) 
  
    # extracting each data row one by one 
    for row in csvreader: 
        rows.append(row) 
  
    # get total number of rows 
    print("Total no. of rows: %d"%(csvreader.line_num)) 
    
    # printing the field names 
    print('Field names are:' + ', '.join(field for field in fields)) 

    #  printing first 5 rows 
    print('\nFirst 5 rows are:\n') 
    for row in rows[:5]: 
        # parsing each column of a row 
        for col in row: 
            print("%10s"%col), 
        print('\n')
# Out:
# Total no. of rows: 75772
# Field names are:Anonymous, Post Number, Folders, Created At, Submission, Submission HTML Removed, Subject, Part of Post, Name, Email, Endorsed by Instructor
#
# First 5 rows are:
#
#         no
#          6
#  logistics
# 2017-10-09 21:06:51 UTC
# <p>Please use the following link to join the &#34;CIS 120 Fall 2017&#34; class from Codio:</p>
# <p></p>
# <p><a target="_blank"> https://codio.com/p/join-class?token=ingrid-slang</a></p>
# <p></p>
# <p>If you have trouble or questions, please post them here.</p>
# <p></p>
# <p></p>
# Please use the following link to join the "CIS 120 Fall 2017" class from Codio:
#
#  https://codio.com/p/join-class?token=ingrid-slang
#
# If you have trouble or questions, please post them here.
#
#
# Codio Account
# updated_note
# Jenny Chen
# jennche@sas.upenn.edu
#       TRUE
#
#
#         no
#          6
#  logistics
# 2017-08-29 20:30:08 UTC
# <p>Please use the following link to join the &#34;CIS 120 Fall 2017&#34; class from Codio:</p>
# <p></p>
# <p><a target="_blank"> https://codio.com/p/join-class?token=ingrid-slang</a></p>
# <p></p>
# <p>If you have trouble or questions, please post them here.</p>
# <p></p>
# <p>#pin</p>
# Please use the following link to join the "CIS 120 Fall 2017" class from Codio:
#
#  https://codio.com/p/join-class?token=ingrid-slang
#
# If you have trouble or questions, please post them here.
#
# #pin
# Codio Account
# started_off_note
# Steve Zdancewic
# stevez@cis.upenn.edu
#       TRUE
#
#
#         no
#          7
#  logistics
# 2017-08-29 23:15:45 UTC
# <p>I wanted to switch my recitation from 212 to 218 in order to sign up for another class. I filled out the form on the CIS 120 website. Am I also allowed to switch it in PennInTouch so that I can sign up for the other course?</p>
# <p></p>
# <p>Thanks,</p>
# <p>Josh Cohen</p>
# I wanted to switch my recitation from 212 to 218 in order to sign up for another class. I filled out the form on the CIS 120 website. Am I also allowed to switch it in PennInTouch so that I can sign up for the other course?
#
# Thanks,
# Josh Cohen
# Switching Recitations
# started_off_question
# Josh Cohen
# joscoh@sas.upenn.edu
#      FALSE
#
#
#         no
#          7
#  logistics
# 2017-08-30 10:28:25 UTC
# <p>Please do not make the change yourself on PennInTouch.  We will contact you once the change has been made.  (If you try to enact the change yourself on PennInTouch, you might accidentally be dropped from the class due to not having a recitation.  The class is full, so you would not be able to re-register.)</p>
# Please do not make the change yourself on PennInTouch.  We will contact you once the change has been made.  (If you try to enact the change yourself on PennInTouch, you might accidentally be dropped from the class due to not having a recitation.  The class is full, so you would not be able to re-register.)
# Switching Recitations
# started_off_i_answer
# Steve Zdancewic
# stevez@cis.upenn.edu
#      FALSE
#
#
#         no
#          7
#  logistics
# 2017-08-30 13:26:23 UTC
# <p>Professor,</p>
# <p>Thanks for letting me know. Unfortunately, since I hadn&#39;t heard anything and I wanted to make sure I got the class materials/homework for the other class, I switched the recitations on Pennintouch. I specifically chose 218 since it was listed on the lecture notes as needing more students. Is there any way I can keep this recitation so I don&#39;t have to switch out of the other class? If not, I will switch back to my original recitation in PennInTouch and temporarily drop the other class. </p>
# <p>Thanks for all your help and I&#39;m really sorry for all the trouble.</p>
# <p>Josh</p>
# Professor,
# Thanks for letting me know. Unfortunately, since I hadn't heard anything and I wanted to make sure I got the class materials/homework for the other class, I switched the recitations on Pennintouch. I specifically chose 218 since it was listed on the lecture notes as needing more students. Is there any way I can keep this recitation so I don't have to switch out of the other class? If not, I will switch back to my original recitation in PennInTouch and temporarily drop the other class.
# Thanks for all your help and I'm really sorry for all the trouble.
# Josh
# Switching Recitations
#   followup
# Josh Cohen
# joscoh@sas.upenn.edu
#         NA
