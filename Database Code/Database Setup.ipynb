# %%
import MySQLdb
import csv
  
# csv file name 
filename = "contributions.csv"

myDB = MySQLdb.connect(host="seniordesign.cbvhmgr3ve3r.us-east-2.rds.amazonaws.com",port=3306,user="grlpwr",passwd="ourseniordesignproject",db="seniordesign")
myDB = myDB.cursor()

# %%
myDB.execute("DROP TABLE CIS120")
myDB.execute("CREATE TABLE CIS120 (question_number INT, "+
             "topic VARCHAR(500), subject VARCHAR(500), question VARCHAR(2000), answer VARCHAR(2000), num_times_referred_to INT, "+
             "follow_up_number INT, endorsed INT, PRIMARY KEY(question_number, follow_up_number))")
# Out:
# 0

# %%
# myDB.execute("INSERT INTO CIS120 (question_number, topic, question, answer, num_times_referred_to, " +
#              "follow_up_number, endorsed) VALUES (1, 'hw1', 'Q', 'A', 0, 0, 0)")

# %%
# initializing the titles and rows list 
fields = [] 
rows = [] 
  
# reading csv file 
with open(filename, 'r', encoding="utf8") as csvfile: 
    # creating a csv reader object 
    csvreader = csv.reader(csvfile) 
      
    # extracting field names through first row 
    fields = next(csvreader) 
  
    # extracting each data row one by one 
    for row in csvreader: 
        rows.append(row) 
  
    # get total number of rows 
#     print("Total no. of rows: %d"%(csvreader.line_num)) 
    
    # printing the field names 
#     print('Field names are:' + ', '.join(field for field in fields)) 

    #  printing first 5 rows 
#     print('\nFirst 5 rows are:\n') 

    curr_question = ""
    curr_text = ""
    curr_topic = ""
    curr_folder = ""
    curr_answer = ""
    curr_number = 0
    curr_follow_up = 0
    endorsed = 0
    
    # This will help us take the most recent version because it always comes first
    already_filled = 0
    for row in rows[:]: 
        # parsing each column of a row 
        for col,field in zip(row, fields): 
            if(field == "Post Number" and curr_number != int(col)):
                if(curr_question != "" and curr_answer != ""):
                    print(curr_question)
                    print(curr_answer)
                    print("\n")
                    sql = "INSERT INTO CIS120 (question_number, subject, topic, question, answer, num_times_referred_to, "\
                    "follow_up_number, endorsed) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)" 
                    val = (int(curr_number), curr_folder, curr_topic, curr_question, curr_answer, int(0), int(curr_follow_up), int(endorsed))
                    myDB.execute(sql, val)
                curr_number = int(col)
                curr_follow_up = 0
                curr_question = ""
                curr_answer = ""
                curr_topic = ""
                endorsed = 0
                
            elif(field == "Submission HTML Removed"): #the question could also be in subject
                curr_text = col
                
            elif(field == "Subject"): #We want to check if this is actually the question eventaully
                curr_topic = col
                
            elif(field == "Folders"):
                curr_folder = col
                
            elif(field == "Endorsed by Instructor"):
                if(col == "TRUE"):
                    endorsed = 1
                else:
                    endorsed = 0
                
            elif(field == "Part of Post"):
                if(col == "started_off_question"):
                    if(already_filled != 1):
                        curr_question = curr_text
                    alread_filled = 0
                elif(col == "updated_question"):
                    # update question entry to post and follow up numbers
                    if(already_filled != 1):
                        curr_question = curr_text
                        already_filled = 1
                        
                elif(col == "updated_i_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled != 1):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                    endorsed = 1
                elif(col == "started_off_i_answer"):
                    if(already_filled != 1):
                        curr_answer = curr_answer + "\n" + curr_text
                    alread_filled = 0
                    endorsed = 1
                    
                elif(col == "updated_s_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled != 1):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                elif(col == "started_off_s_answer"):
                    # append to answer - if it was previously endorsed and were appending should we keep it endorsed?
                    if(already_filled != 1):
                        curr_answer = curr_answer + "\n" + curr_text
                    alread_filled = 0
                    
                elif(col == "followup"):
                    # new entry for the new followup question 
                    if(curr_question != ""):
                        print(curr_question)
                        print(curr_answer)
                        print("\n")
                        sql = "INSERT INTO CIS120 (question_number, subject, topic, question, answer, num_times_referred_to, "\
                        "follow_up_number, endorsed) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)" 
                        val = (int(curr_number), curr_folder, curr_topic, curr_question, curr_answer, int(0), int(curr_follow_up), int(endorsed))
                        myDB.execute(sql, val)
                        curr_question = ""
                        curr_answer = ""
                        endorsed = 0
                        
                    curr_follow_up = curr_follow_up + 1
                    curr_question = curr_text
                elif(col == "reply_to_followup"):
                    curr_answer = curr_answer + "\n" + curr_text
                                
                
#         print('\n')
# Out:
# I wanted to switch my recitation from 212 to 218 in order to sign up for another class. I filled out the form on the CIS 120 website. Am I also allowed to switch it in PennInTouch so that I can sign up for the other course?
#
# Thanks,
# Josh Cohen
#
# Please do not make the change yourself on PennInTouch.  We will contact you once the change has been made.  (If you try to enact the change yourself on PennInTouch, you might accidentally be dropped from the class due to not having a recitation.  The class is full, so you would not be able to re-register.)
#
#
# Professor,
# Thanks for letting me know. Unfortunately, since I hadn't heard anything and I wanted to make sure I got the class materials/homework for the other class, I switched the recitations on Pennintouch. I specifically chose 218 since it was listed on the lecture notes as needing more students. Is there any way I can keep this recitation so I don't have to switch out of the other class? If not, I will switch back to my original recitation in PennInTouch and temporarily drop the other class.
# Thanks for all your help and I'm really sorry for all the trouble.
# Josh
#
# No worries -- if everything worked out, then there's no need to do anything else.   You're good to go.  (The problem is that PinnInTouch can sometimes kick you out of the class if you don't have the associated lab section, but if you are registered for both a lab section and the lecture, you're fine.)
#
#
# Hi Professor Sheth,
#
# I just saw the homework 01 folder in Codio, and was wondering whether we need to complete it before or after our first class. Could you please help me out?
#
# Hi Lakshay.
#
# No, you don't need to do it before the first class. It's due in just under 2 weeks on September 12.
#
# We'll talk about this (and other logistics) in class today. You can also find the schedule and syllabus on the class website - https://www.seas.upenn.edu/~cis120/current/lectures.shtml
#
# See you in a few hours!
#
#
# Hi,
# This may be my error, but I do not see a date for the final exam posted on the CIS 120 page. Also, the Canvas page for this class does not appear to have been published.
# Are these two resources unavailable right now?
#
# Thanks
#
# 1) Yup, we do not use Canvas for this class. The information you need for the class can be found here: https://www.seas.upenn.edu/~cis120/current/.
#
# 2) We are working on the final exam date right now (it is scheduled by the registrar) to make sure that both sections take it at the same time. We will let you know when it is confirmed.
#
#
# Hi, thanks for the quick answer. I just had a quick follow up question, since I thought that that part of the "rules" only applied to the first part of the assignment. The part I am talking about is the one starting from "The remaining exercises provide practice with lists and recursion.". I thought that that implied that we could use the List functions, but now that I think about it again it does seem like my assumption was made way too fast.
#
# But, just for the record - Something like this would be disallowed since I'm using List.length, List.hd, List.tl and String.sub/String.length, right?
# let rec join (separator: string) (l: string list) : string =
#   let rec pushstring (s : string) (ll:string list) : string =
#     if List.length ll == 0 then String.sub s 0 ((String.length s)-(String.length separator)) else
#     pushstring (s^(List.hd ll)^separator) (List.tl ll)
#   in pushstring "" l
#
# Correct. This would not earn credit. Since there has only been one lecture, I imagine the professors haven't covered the topic necessary to complete the second half of the assignment. However, if you went to self-teach, I would focus on the part of the lecture notes under the section* "pattern matching" and this should show you the ways you can get the "head" and "tail" of the list without needing to use this library. Good luck!
# Right. Thank you very much, I'll do so then.
#
#
# the calendar is blank (?)
#
# We're still working out the rooms where OH will be held. We'll announce all the details when it's updated!
#
#
# If the same element appears twice in the first list, but once in the second list, should it appear once or twice in the final list? Thx
#
# Twice
#
#
# Is this a question you needed clarification about? If so, next time please ask a question instead of posting a note. If this a note to fellow students, please be more specific about how this applies to the course material or homework, or another Piazza question.
#
#
#
# Wait, I thought all helper functions were disallowed? I posted a question a while back and that was the answer I got. Or how do you define helper functions? (As far as I can see I didn't use any, but maybe I did and we're not talking about the same thing)
#
# I think you're referring to the private post you made--let me see if I can clarify.
#
# A helper function is another function that you write yourself somewhere in the assignment. This means that you define it, and you write the implementation for it. However, you are not allowed to use any functions already built into OCaml--for example, you are explicitly not allowed to use "@" for appending two lists in this homework, but that also means you cannot use any OCaml List functions.
#
# We want you to only be using functions/code you've written yourself (for now)!
# Oh, right. That makes absolute sense. Thank you for the clarification.
#
#
# My test case was
#
# let test () : bool =
# (abc 48) = 3
# ;; run_test "48/10" test
#
#
# The test should not be passing. Are you certain your abc function divides the input by 10 and does nothing else?
# yes. The code is simply i / 10
# If you show your code to a TA during office hours, they'll be able to help you find the problem!
# Ok. Thank you
#
#
# That works! Thank you so much.
#
# You're very welcome c: Good luck on the rest of the assignment~
#
#
# I got this:
# Exception File "src/display.ml", lin
# e 176, characters 2-8: Assertion fai
# led.
#
# Unfortunately this is a bit hard to debug remotely. We can try taking a look if you let us know your pennkey/name (feel free to make this post private if you want) or you can try going to office hours.
#
#
# I'm also getting this exact same error. I tried saving all files, but that did not resolve the error.
#
# I just logged on to Codio to look at your project and while you are still getting an error, it's an error on line 576 in intro.ml which can be resolved by adding parentheses around part of your code. Feel free to start a separate thread if this doesn't solve the issue.
#
#
# Hi! I am also getting the exact same error (same line and characters). Any suggestions on how to correct it?
#
# Nevermind it seemed to have fixed itself!
#
#
# I started to get the same error too. Is there anything I can do about this?
#
# I took a look at your code, and it looks like you have a syntax error in intro.ml around line 618. You can also try double checking to make sure that your files are saving in codio.
# So I ended up trying it on Safari and it is working now. Thanks!
#
#
# I'm also getting a similar error message. Is there anything I can do to fix it? I've already tried a different browser.
#
# Exception File "src/display.ml", line 176, characters 2-8: Assertion failed.Compilation unsuccessful after building 1 target (0 cached) in 00:00:00.make: *** [intro.native] Error 100codio@ralph-spell:~/workspace$
#
# I was able to successfully build your project without getting that error (it looks like you have a syntax error on line 142 though). I'm using Chrome if you want to try that! Also try manually saving your files as well (cmd/ctrl + S) before running the project.
#
#
# So just to confirm if I use a snippet of code found in the lecture notes that's allowed? Thanks!
#
# Yes, that's allowed! You can use any of the tools provided to you in class/notes
#
#
# Oh, so technically if I wrote x=5 and x=17 later in the code then there are two "x"s that exist (unlike java where the value of 5 in the box "x" will be replaced by 17).
#
# Exactly!
# Thank you :)
#
#
# Interestingly, when my input is "coins -10" I get this error but when my input is "coins 10" in the test cases I don't get an error:
#
# make: *** [run] Error 1codio@silence-union:~/workspace$ make all &amp;&amp; clear &amp;&amp; make runocamlbuild -lib graphics intro.native+ /home/codio/.opam/4.04.0/bin/ocamlopt.opt -c -o intro.cmx intro.mlFile "intro.ml", line 81, characters 1-6:Error: This expression has type int -&gt; intbut an expression was expected of type intCommand exited with code 2.Compilation unsuccessful after building 8 targets (6 cached) in 00:00:00.make: *** [intro.native] Error 10codio@silence-union:~/workspace$
#
#
# Does ocaml not recognize -10 as an int? Thanks Saran!
#
# You may need to put parentheses around -10, i.e., coins (-10). Otherwise the coins function is taking in "-" as the input, which is a function of type int -&gt; int. You'll learn about function types later, but for now just know to put parentheses around negative inputs!
# Thank you, Allen!
#
#
# Would you also recommend putting in cases for when the street is below 0 or above 69, and putting a "failwith" for these cases? Or is that not proper/not required?
#
# Re-read the instructions - I believe there is a specified behavior for those cases!
# EDIT: See above.
# Oh, sorry. Didn't see that. Thank you!
#
#
# I'm terms of style is it better to combine streets to have less code or to have explicitly different cases--which creates longer code but more explicitly shows what you're checking for?
#
# There is a tradeoff here, which you can definitely discuss with your TA during the code review for this HW. If you write shorter, less explicit code, you may want to add a comment to clarify which cases it covers. However, writing a separate case for every single street does not seem like the cleanest way to approach this problem.
# Where would you put the clarifying comments if the "if/then/else if" statements for all of the cases exist on the same line?
# I didn't mean a separate case for every individual street-I meant combine the streets that go the same direction but are in different parts of the city vs have a separate line for each section of the city/each section of the question. Anyway, thanks!
# If it's clear what the cases are checking, there's no need to add a redundant comment. However, if you have some convoluted math (like using mod or something) or an "else" such that it's not clear what the else is handling, you could add a comment right above it or on the same line as the code.
#
# Also note that the official CIS 120 style guide limits lines to 80 characters, so if you have everything on the same line, you should be adding in some line breaks and you can intersperse the comments accordingly.
# Thanks for clarifying! I think that organizing the problem by direction and not worrying about the part of the city would be just fine.
# What would be the appropriate style for separating "if/then/else if" statements into different lines? Or is it just line breaking arbitrarily/to one's discretion?
# http://www.seas.upenn.edu/~cis120/current/programming_style.shtml#22 (hopefully this links to the right subsection of the style guide!)
# Thanks so much!
#
#
# File "intro.ml", line 285, characters 0-3:Error: Syntax error
#
#
#
# Double-check your street_direction function.
# On line 272 it looks like you have the function declaration copied/pasted twice? I'm not sure if that's causing the error, but regardless that should be deleted. I think the reason it's pointing to the empty line is because there is actually an error in the lines above it. I haven't looked deeply into the logic you've written, but you should also be very careful with your use of parentheses - a lot of times OCaml gets finicky if you use them in the wrong place or omit them when they should be included - additionally make sure that every open paren has a matching closed paren. Hopefully one of these suggestions works - if not definitely stop by office hours!
# Exactly-- that is not even showing up on my codio screen!! There is only one declaration, and when I hit "reload" it litters the body of that function with unnecessary parentheses, sometimes even things like )))()). I'll stop by office hours, but again, my code works fine in the command line and via XCode  I shouldn't face any grading penalties because of erroneous code on Codio, right? Sorry for being extra!
#
# This is strange, since I see something different when I look at your code through Codio. This is our first semester using it so we apologize for the issues you're experiencing! - you could definitely show this to the professors so that they can help you fix it for future assignments. In the meantime, definitely use whatever text editor or IDE you feel comfortable with; however the staff does not officially support other IDEs except Codio.
# Also, you will only be graded on what you submit via the CIS 120 submission page, so you won't be penalized for this. It's always good to clarify!
# One easy-to-try suggestion: try a different browser and let us know if this problem persists.
# If function is returning string, the entire expression string1 ^ string2 ^ function (list) should evaluate to string.
#
# For example, using "https://try.ocamlpro.com/, which is online OCaml IDE, I tried following:
# let simpleListToString (l: string list) : string = "an example"
# and tried following expression
# "This " ^ "is " ^ simpleListToString ([])
# and it returned
# "This is an example"
#
# So, "yes" to your first question.
#
# For your second question, I suspect that, since your error message states that "it is expecting a string and not a list", you might want to check input type of the function you are using (or any other function that is expecting a string as an input, not a list.
# Hope this helps!
#
# Yes this helps a ton, thank you!
# I am glad that it helped! Error messages are crucial when debugging :)
#
#
# I'm having a similar issue. So if you said | x::y::rest -&gt; , would the y refer to the second item in the list? Because when I tried that it looked like the program interpreted that to be the "rest" of the list.
#
# In that pattern match, y will refer to the second item in the list.
#
#
# The first command: ocamlbuild -lib graphics &lt;filename&gt;.native worked fine, but the second command: ./&lt;filename&gt;.native gave an error. It says: No such file in directory.
# Do you have any idea why this might happen?
#
# It works now.
#
#
# Thanks for catching that! However the error is persisting and the message on the console says its located at the two semicolons in the first test case. How can this be? Aren't they necessary for the command to run the test?
#
# let test () : bool =
#   (append [] []) = []
# ;; run_test "append two empty lists" test
#
# let test () : bool =
#   (append ["1"; "2"] ["3"]) = ["1"; "2"; "3"]
# ;; run_test "append different lengths" test
#
# let test () : bool =
#   (append ["Hi"; "I"; "Love"; "You"] []) = ["Hi"; "I"; "Love"; "You"]
# ;; run_test "append one nonempty and one empty" test
#
# let test () : bool =
#   (append [] ["2"; "3"; "4"]) = ["2"; "3"; "4"]
# ;; run_test "append empty to nonempty" test
#
#
# This is an issue that appears in many of the questions even if I havent written any code in the section.
# Chances are it's actually a syntax error higher up, in some of the code you wrote to implement a function. OCaml sometimes doesn't notice that the syntax error is actually causing a problem until later down in the file.
#
#
# Okay, say if the initial position is 105 but it moves backwards 10, then is the position now 95 or should it automatically return 99
#
# It should return 95 in that case.
#
#
# oh, i thought putting "in" at the end of my conditionals in the function separated it
# new_pos is within the scope of itself?
#
#
# Nothing is syntactically wrong in your code from what I can see.
# Sam's answer is more related to style rather than pure "syntax" or "grammar" - which means you would not have an error with that code. :)
# Side Note:
#
# Piazza is not the best mean - or a right place - to check OCaml syntax. :(
# You can "check" syntax by trying to build your code in Codio! :)
# Piazza is more useful for questions pertaining to specific concepts, errors, etc.
# Thank you! The terminal didn't indicate a syntax error for this one. It is, however, indicating a syntax error for this
#
# ;; print_endline ("The new position is " ^ (string_of_int (move_robot 10 "forward" 3)))
# which i am trying to use to correct my code. it indicates line 0-2 as the source of error?
# nevermind, i have resolved
#
# Awesome!
# To check for equality, you should be using single equals (=), not double equals (==)
#
#
# I'm just wondering the correct way to print within a function. I have tried the following with syntax errors:
# ;; print_endline "hello"let _ = print_endline "hello"
# Also wondering what the difference between using double semicolins at the beginning and end of a line is. Thanks!
#
# At this point in the class, it is best to print using the let _ = print_endline method. Once you learn about the type "unit", semicolons may be useful for printing items.
#
# Make sure you follow
#
# let _ = print_endline "hello" in
# with the rest of your expression! For example, if you want a function that takes in two ints and prints and returns their max, it would look like this:
#
# let printMax (num1 : int) (num2 : int) : int =
#     let maxNum = max num1 num2 in    let _ = print_int(maxNum) in
#     maxNum
# The first line calculates the max and assigns it to maxNum, the second line of the function will print the max, and the final line will make the entire function evaluate to the max.
#
#
# What can I do to access the elements of more than one list?
#
#
#
# You can do something like below:
#
# (This is from Lecture 4 Slide 31)
#
# Or do nested pattern matching
#
# (This is from CIS120 Textbook/Note page 64)
#
# Lecture Notes and Textbook are really helpful when it comes to syntax and concepts :)
# When you are stuck or confused, do check them out.
#
#
# I just realized my mistake. I was trying to pattern match integers to variables that I assigned to integers. So for example for a : int = 5, I tried to pattern match 4 to a, and those matched. Is there a way to pattern match things onto variables assigned to certain values/strings, or do you just have to use if/then/else statements?
#
# If/then/else can always work, and is typically sufficient for looking at one specific int value or class of values. I'll give an example below for the syntax of pattern matching an int, but I'd argue that even for this example, if/then/else is probably a suffcient approach.let num_enrolled_students = (*some integer value*) inbegin match num_enrolled_students with| 28 -&gt; "full recitation"| 27 -&gt; "almost full recitation"| _ -&gt; "open recitation"endThis will evaluate to a string telling us how full a recitation is, for any input - that is, we don't already know th  number of enrolled students beforehand. The underscore, or wildcard, is a "catch all" for all other int values besides 27 or 28.Feel free to follow up if this wasn't what you were asking!
#
#
# So would you include the cases in which one list is empty and the other is non-empty after
# hd1 :: tl1, hd2 :: tl2 -&gt;
# or before it?
#
# Whichever one you put first will be matched with first, so it may depend on what you want in your implementation. In general, however, you will have the case of one empty and the other non-empty first. So it may look something like
# begin match l1, l2 with| [], [] -&gt; ...| [], x2 :: t2 -&gt; ...| x1 :: t1, x2 :: t2 -&gt; ...| _, _ -&gt; ...end
# Note that the last case uses two wildcards, basically to catch any of the cases that were not covered by the previous three cases. It is kind of like "anything else goes in this case". In this example, the only other case would be where the first is non-empty and the second is empty, but in general any unused cases you'll want to cover with a wildcard.
#
#
# I do actually. The terminal is giving me this error about begin and end, so maybe it has something to do with my matching setup? Though I'm pretty sure I did it the way you're supposed to
#
# File "intro.ml", line 550, characters 54-55:Error: Syntax error: 'end' expectedFile "intro.ml", line 548, characters 2-7:Error: This 'begin' might be unmatchedCommand exited with code 2.
#
# do you follow you begin match with an "end"? Begin match must always be followed by a corresponding end, as follows:
#
# begin match l with
# |...
# |...
# end
#
# So I seemed to have resolved that error, but I'm still struggling with referring to the second item in the list. I able to do "x::y::rest", and compare x and y, but then when I try to recursively call the function by using "y::rest", the program says I can't use the "::" because the eventual output is a bool. Is there a way to get around this, because I need to include y in calling the function so I can compare it to the next value.
# Try putting parenthesis around (y::rest). Without the parentheses, the compiler sees y::rest as multiple arguments to the recursive call for when it only expects one
#
#
# From what I understand, the function fails because it essentially groups the elements of the lists into 2's and checks within each pair to see if they're ascending, so it fails when there are consecutive numbers that aren't paired together and aren't ascending (like in [3; 4; 2; 5], the 4 and the 2 are consecutive but aren't checked because they aren't paired). Would it be an acceptable solution to write a helper function that just pulls out the first term of a list and use that to fix the issue?
#
# Thanks
#
#
# You're exactly right about what the problem is! You could definitely try writing a helper function, but it might be easier to just think about how you could change your pattern matching case.
#
# Think about it like this; if you run the function on [3; 4; 2; 5], you first compare 3 to 4 and then run the function on [2; 5]. How could you make it so that you run the function again on [4; 2; 5] instead?
# Would this entail adding new pattern matching scenarios or is there a way to just directly call forth the list y :: tl? I tried just using y :: tl but that gave me an error message.
# That's the right idea. It sounds like you might've had a syntax error--try wrapping (y :: tl) in parentheses.
#
#
# It seems to happen, at least to me as a result of the fact that I don't see a way to stop the running code if it's stuck in an infinite loop.
#
# If you type "CTRL-C"  (the control key + 'c') in the terminal window that is executing your code, it should stop.
#
#
# I have refreshed several times and am still getting this error. Any update on what to do about this?
#
# Try closing all the terminal tabs in Codio.  Then use the "Clean Project" menu item.  Then try the "Build Project" item and look to see if there are any different errors / warnings.
#
# If you don't get any errors, it is likely that one of your functions is going into an infinite loop (you can use CTRL-C in the terminal to kill it).  You might try stubbing out the looping function with a failwith to see if that truly is the problem.
#
# If none of that works, your best bet would be to stop by office hours sometime tomorrow.
# Thank you!
#
#
# Hmm, that's odd. I am on the intro.ml and this is what I have
#
#
#
# Oh! So you have your edits in intro.ml under the build folder. Can you try copying and pasting that to the intro.ml outside of the build folder and then running the project? Tell me if anything changes!
# Yes, that worked! Thank you so much!
#
#
# thank you.
#
# Actually, I'm sorry but I accidentally misinformed you. :C Please look at the updated answer for reference.
# It also is in the FAQs :) @43
# Alright, ill double check my test cases once again, using this new information, and remove my failwith clause.
# FYI In general, you should try to not submit code with failwiths.
# let rec exists (bools: bool list) : bool =
#   begin match exists with
# | [] -&gt; false
# | x::tail -&gt; (x == true) || exists bools
# end
# Can you explain the following error? I thought that the above code would in fact generate a bool value / output the result of the second branch
#
#
# You shouldn't be using "==" to compare whether x is equal to true. In OCaml, you only use the single "=".
# You cannot pattern match against a function.
# Also, make sure that your recursion terminates.
#
#
# Right, I understand the type thing which is why I asked--but my reasoning for why it could possibly be allowed was that technically I am sticking to the function stub and simply writing a helper function (that happens to do all the work, instead of part of the work) to use in sublist....So I just want to check you were addressing that reasoning in your answer above.
#
# Thanks!
#
# Oh I see--I didn't notice the original stub at the bottom! This should be fine for submission/grading. But keep in mind that when we start grading style, this might cause you to lose points (we aren't for this homework)!
#
#
# Thanks for the quick reply!
#
# I'm also having trouble with the next part of question 6. When making the int_join function, how can I convert an int to a string. For example, if I just wanted to make the int 1 into a string "1" why can I not just do "" ^ 1 or something along those lines?
#
# 1 is of type int and will not change to a string unless you explicitly use string_of_int, and ^ only  works on strings (is of type string-&gt;string-&gt;string)
#
#
# Good Evening Instructors
#
# It still says that there are no current assignments.
#
# Best
#
# Sorry for the delay! We have a job that runs automatically every morning to enroll people in the class, so I'm not sure how your registration got skipped. Please send an email to cis120@seas.upenn.edu explaining your situation and one of the professors should be able to take care of it! In the event this doesn't get resolved before the homework deadline, you wouldn't be penalized for a late submission.
#
#
# Isn't Tuesday at 11:59 a little under 48 hours from now?
#
# Yup! Mistype :)
#
#
# What is the difference between an error and a failure? Thanks!
#
# See @145
#
#
# Do we have to include test functions for every helper function we make on our own??
#
# You don't have to, but it would be a good idea for debugging and making sure it does what it does.
#
#
# I would probably just take the values in the first list and then one by one match them with each sequence of the same length of the second list. So if the lists looked like [a, b] and [a, c, d, e] I'd want to match  a, b with a, c; then a, b with  c, d; and so forth.
#
# For the helper function, I was thinking it may be useful to write a helper function that would find the length of the first list and then extract its values? I'm really not sure on the helper function.
#
# Ah, so you realize you have to match all of l1 with parts of l2. How would you normally do this?
# I would probably do something like
#
# let rec sublist (l1: int list) (l2: int list) : bool =  begin match l1 , l2 with  | [] , [] -&gt; true  | [] , y:: tl -&gt; true  | x::tl , [] -&gt; false  | x::tl , y::tt -&gt;
#     if (x::tl) = *sequence from the 2nd list being matched* then true else sublist l1 tt
#
# How would you go about finding the length of the 2nd list that must be matched? Also, I don't think my style in this instance is very efficient. Is there an easier way to call forth the values of the entire list?
#
# You're very much on the right path :D
#
# You're looking for a function that can match the first list to a sequence in the second list. Do you think a helper function could do this for you?
# So would the helper function just be a function that only does the matching? Also, I'm still confused as to how I would ensure that the sequence from the list has the same length as the first list; is there a way to code that?
# If you could find a way to get your helper function to match l1 with an entire sequence of l2, the length wouldn't matter, right?
# I tried for a bit but I'm still not quite sure how this would work. Wouldn't I need to take the entirety of l1 and then pull out a sequence of equal length from l2?
# Actually, you don't need to do that if you pattern match!
# let check (l1 :int list) (l2: int list) : bool =  begin match l1 , l2 with  | x::tl , y::tt -&gt;  if (x::tl) = (y::tt) -&gt; true else false end
#
# Would something like this be valid? I'm not quite understanding how to ignore the issue of length. (Ignore that it's not exhaustive).
# Hm, if I asked you to compare [1;2;3] and [1;2;3;4] with pattern matching, how would you do it? Your current solution only checks if the first values are the same. Can you use recursion to solve this problem?
# I'm actually not sure how I would do that.
#
# Also, wouldn't the code above match the lists in their entirety because of the parentheses?
# Oh, I see. Since you're running into difficulties trying to find the length, what if you pattern matched both lists at the same time and compared each corresponding element? So in my given example, match 1 with 1, 2 with 2, etc? Do you see how this can work?
# Yes, I think I know somewhat.
#
# let rec check (l1 :int list) (l2: int list) : bool =  begin match l1 , l2 with   | [] , [] -&gt; true  | [] , y:: tl -&gt; true  | x::tl , [] -&gt; false  | [x::tl] , [y::tt] -&gt;  if x = y then check tl tt else check l1 tt
# end
#
# However, how would I use this in the problem?
# So your code right now would return true for [1;2] [1;3;4;2], which we don't want because we want to make sure the elements in list one are next to each other.
#
# And how would this function fit? Well, earlier, you wrote:
# let rec sublist (l1: int list) (l2: int list) : bool =  begin match l1 , l2 with  | [] , [] -&gt; true  | [] , y:: tl -&gt; true  | x::tl , [] -&gt; false  | x::tl , y::tt -&gt;
#     if (x::tl) = *sequence from the 2nd list being matched* then true else sublist l1 tt
#
# It would be super nice if this current function could do the bolded part for you, right?
#
# 1. How would I fix the check function so that it doesn't return true for [1;2] [1;3;4;2]? I was thinking about changing the part after the else to false, but then that wouldn't check the later terms.
#
# 2. It would, but I'm still not understanding how writing a helper function would bypass the issue of needing the length of the sequence from the 2nd list because the input into the helper function has to be either l2 in its entirety or just the sequence being matched (which would require the sublist function to pull it out the correct length).
# 1. That's actually exactly what you need to do. This is because you don't care if later terms check, you would just like to see if the first part of the second sequence matches. This takes care of the length issue so you don't have to care.
#
# 2. So if you have the first function to use as a helper function, you can now replace the previous bolded part with a call to the helper function.
# Ok I finally understood it. Thank you so much I got the code to work. :D
# c: Nice!
#
#
# Well, there's no reason why it wouldn't work, since it worked for me a second ago as well ... But now I just keep getting "error in display.ml"... Is there a way to clear some kind of codio internal cache?
#
# Weird, now it started working again. How.
# And now I get the same error again...
# Try doing a "Clean Project" and "Run Project" - that might help as well.
#
# Someone showed me a similar thing after class today and that seemed to fix it in their case.
# Worked. Thanks.
# Great! Is it ok if I make this post public? It might help others.
# Sure thing, go ahead.
# And now it doesn't work once again, even though I did not change anything... And clean project doesn't work either...
# Thanks for bearing with us as we try to figure out what is going on!
#
# We've notified the Codio folks about this issue, but unfortunately there seem to be a variety of ways that the issue is eventually solved (and the issue is hard to reproduce for some reason).
#
# You can try these (possible) solutions to try and fix the issue:
# Save the filesClean/Build/Run the projectClose/logout of Codio and then log back inExit out of your browser, then reopen it (also maybe try incognito/private browser mode)Switch browsers (some people have said using Safari solved the issue, personally have been using Chrome and seemed to work)
#
# In your homework 2, when I ran it I see this error:
# File "dna.ml", line 542, characters 15-20:Error: This variant expression is expected to have type helix       The constructor LLeaf does not belong to type list
#
# Yeah, there is an error on that line. But the problem is that I can't even see the error log because I only get the display.ml error... Now I even get the display.ml error when I'm trying to press clean project.... I'll try downloading another browser....
# Okay, codio does work in edge. But it is really, really, really laggy. (Takes 20seconds to scroll)
# I guess I need a better laptop.
# display.ml in edge...
# Is there a way for us to do the homework without Codio? I've tried three different browsers now, and in all of them it just sometimes work and sometimes doesn't. First few times just cleaning the project and building it again works, but after a while even that stops working, no idea why.
# Yes, there is. You can download Eclipse and set up OCaml there. Here are the setup instructions: https://www.seas.upenn.edu/~cis120/current/ocaml_setup.shtml
# Installer is outdated. Should I try another one or just pray that codio starts working again before Tuesday night? Clearing cache/cookies, switching browser, ... nothing works...
# 1) As a last resort, all the computers in Moore 100A should have Eclipse/OCaml installed.
#
# 2) I don't have windows, so unfortunately I can't try this out myself to make sure it works, but even though there is a warning that the installer is out of date, it still provides a link to download OCaml. You can try that and see if Eclipse will still be properly set up, etc. That webpage also links to another installer you can try if that outdated version doesn't work: https://fdopen.github.io/opam-repository-mingw/installation/. There are office hours from 6-8 if you want to sit with a TA to try and setup Eclipse with OCaml.
#
# If your codio is frequently running into this error, I would strongly suggest going to office hours (especially the professor's if you can make it) because then they can physically see the error and hopefully see if there is a methodical way to resolve the issue.
#
#
# wow, can't believe I didn't see that :D
# Thanks
#
# lol it took me 37 min to see don't feel bad!
#
#
# Well, I am using it to get the head of the second helix in the hamming_distance function to check if the two heads are equal. Maybe you can suggest a different way of doing this? Maybe a different pattern match? Can you pattern match two lists at once? Or maybe a nested pattern match?
#
# You can do 2 lists at once or a nested pattern match!
# I got it! Thanks!
#
#
# Under the hood, there should be no difference in terms of computing speed between the two. [1; 2; 3; 4] is merely "syntactic sugar" for 1 :: 2 :: 3 :: 4 :: [], which means that at compile time they are reduced to the same instructions via a process referred to as desugaring. That being said, these details are beyond the scope of CIS 120 but are probably covered in CIS 341 if you find them interesting.
#
# Thanks!
#
#
# Sorry I can not clearly see if the separator is still there. Given separator ";", would it be ";a;b","a;;b" and "a;b;;" ?
#
# Lol sorry bad choice: you're right about the first two. The last should be "a;b;"
# Just for clarifying: we ignore the separator if an empty string is at the end of the string list?
# No, in general, we don't put a separator after the last element of any list.
#
#
# The last test case for sublist is not an error, it should be written correctly as is. sublist [2;3] [2;1;3] should be false since [2; 3] is not a sublist of [2; 1; 3], and the "not" preceding (sublist [2;3] [2;1;3]) negates the final value from false to true so that the test case should pass.
#
# not (sublist [2;3] [2;1;3])not (false)true
# For question 12, and I guess this goes for all questions, do we only have to pass the tests written explicitly in the Codio file? My sublist function works for the 4 written test cases, but it doesn't work for a test I created myself: (sublist [1;2;3] [1;4;5;2;1;1;2;3])
#
# Do we only need to pass the test cases written in Codio to receive full marks, or is there another set of test cases written elsewhere?
#
# We use a separate set of test cases on submission, so you should definitely write your own test cases and pass them!
#
#
# So that means that I have to go back and delete all of those extra pattern matching cases in order to submit the assignment?
#
# Yes. Your pattern matching cases should never be extraneous.
# Or non-exhaustive for that matter.
# So the first warning says "this pattern match case is not exhaustive" which means you're actually MISSING a case - it gives you an example of the case you're missing, and you should add it.Warnings (as opposed to errors) don't prevent you from submitting the assignment, but they're typically a signal that your style can be improved, so you might want to edit that or ask your TA about it during the code review.
#
#
# Are we supposed to simply replace the failwith with a helix list corresponding to the sorted int list or shall we write some codes for the sorting process?
#
#
#
# There should be no int lists in question_most_like_human(). Notice all it does it return a helix list, so you can just replace the failwith with a helix list.
#
#
# Do you get actual bonus marks for doing it, though? Or is it just for practice.
#
# It's just for practice.
#
#
# Thanks for the quick response Emma, but I'm actually working on Eclipse (I don't have wifi at my house so I need to work offline). Anything I can try in Eclipse?
#
# Make sure that you include only the intro.ml file in the zip file that you submit.  Do not include any of the generated files (in particular the intro.cmi).
# It looks like you included the compiled files in the zip.
# Got it, thank you!
#
#
# This makes sense for variables. So you cannot pattern match against general types?
#
# so you couldn't say:
#
# int:: int:: tail
#
# ?
#
# That's correct. You have to give them names, sometimes we call those "bindings"
#
#
# also I changed the values to be nucleotide1:: nucleotide2:: [] and now the terminal says the function find_start_codon is unbound. How should I go about debugging/fixing this?
#
# Thank you SO much!
#
# I believe it just has to do with the ordering of your code. You can't call a function unless it is defined ABOVE the code where you call it. I have a feeling you currently define the function BELOW the place you are trying to call it
#
#
# ok, thanks, I got it. Also, just to clarify, we don't need to fill in the empty test cases for only this first homework, correct?
#
# Great!
#
# You're expected to fill in the given test cases and write your own tests to comprehensively test the functions in each of the homeworks for this class.
# i thought on the first homework the style and test cases weren't going to be graded on?
# The ones that are there should be filled in by you. We won't be grading on style and test cases this time around but it's always good practice to have good style and good test cases.
#
#
# I tried cleaning the project as suggested, but it's still having the same issue.
#
#
# If you want to post your name here or in a private post, I can take a look at the code? Are you sure the work has saved and there are no errors?
#
#
# I keep getting this error even though it's submitted...
# Screen_Shot_20170913_at_12.20.05_AM.png
#
#
# So it submitted but it says it is 1 day late. Did you submit it after midnight?
# Unfortunately, when you submitted before midnight, it did not compile. If there is an easy-to-fix syntax error that prevented it from submitting on time, you can bring this up with your TA during the code review and it's possible the TA/professors will give you the full credit.
# In the future, note that code must compile in order to be considered "submitted" - it will show that tests ran against the code, and it will show you a score. The submission receipt you get via email is another form of confirmation.
#
#
# So if we have a tree with multiple helixes, we should return all of them?
#
#
# Is this about unlabel_tree or helix_of_tree (they are both under Q5).
# For helix_of_tree, we just want the "root" helix. So if it's a tree with multiple helices, we just want the root, or the main parent helix.
# Ok, thank you
#
#
#
# I am on a different wifi network as I live off campus.
#
# It doesn't load for me like 75% of the time in the Radian (Pavlov Media). Not sure if that's where you are, but you should try working somewhere on-campus to see if it will load.
# Yeah that's where I am. Okay thanks.
# Weird that it's loading for me right now in the same building... sorry I can't help you more. I know people have complained to the Radian about it before but I don't think they ever found a way around it.
#
#
# So for HW problem 2,
#
# hamming_distance ([G; A; G]) ([C; T; C]) should return 3?
#
# Correct!
# thanks a ton
# No problem :)
#
#
# So, is it supposed to return a list of all helices/ helixes (I am not sure about the word) or just of the node on the top?
#
#
# Just the top one :)
#
#
# But in that function, aren't we removing the helix information from all nodes? Because we are trying to eliminate the "guesses"
#
# You're correct--you're supposed to remove the helix from each Node in the tree, and leave the leaves (vertices without any children) as the only items that have helix data. Then, add_ancestor_label will use these remaining helices of the leaves to guess the helices of the Nodes.
#
#
#
# So just to clarify, for unlabel_tree, if the only argument is an LLeaf, we leave LLeaf as it is (don't remove the helix)?
#
#
# If the entire tree is just one LLeaf, then there are no guesses to remove.
#
#
#
# How is A opposite of T and G opposite of C here? Thanks!
#
#
#
# I think the diagram is throwing me off but my understanding of the problem is if the input is AGTAC then the output should be TCATG, is that correct?
#
# Yea don't worry about Figure C yet, that is for later when you are generating trees. For problem 1, Figure B may be helpful in visualizing the nucleotide matching. Your understanding here is correct, AGTAC should output TCATG!
# Thanks Allen! :)
# No problem! We definitely don't want a biological misunderstanding to deter anyone from doing this HW.
#
#
# I'm still recieving an error on Line 283 of my code. Could a TA take a look at it?
#
# It looks like you're missing an "in"
#
#
# I meant more the line spacing, indents, length of lines--anything that's not the content of the tests or names of the test...
#
# The general rules that apply to your main code will also apply to tests in those terms as well. So yes, be consistent with line spacing, indents, etc.
#
#
# What's the correct syntax for the actual test? Such as for hamming_distance [] [A]? Should you just equal it to anything (ex. 0) and then use run_failing_test and it'll ignore the equality?
#
# Yup that works! Because if it is written correctly, it should fail before it reaches the = sign.
#
#
# I've deleted the "rec" for some of the function declarations in Homework 1 and all the automated tests passed. I've deleted some of the "rec"s in Homework 2 as well before I read this, and now I can't remember which functions had a rec in them. What should I do?
#
# You can go to this page: http://www.seas.upenn.edu/~cis120/current/hw/hw02/ - download a fresh copy of the files, and compare the fresh copy to the copy you've edited.
#
#
# Can we assume that the length of the helix after TAC is a multiple of 3?
#
# Also no.
#
#
# Is it ever possible for the acid_of_trip to NOT start with MET? (Asking so I know how my test should respond) :)
#
# If the TAC is never found, the function should return an empty acid list
#
#
# For
#   |x1::y::z::tl-&gt;if acid_of_triplet(A T T) = acid_of_triplet(x1 y z) then []
#                  else acid_of_triplet(x1 y z)::starts(tl)
#
# I got Syntax error: operator expected, but at where my operator is missing?
#
# You don't want to have the parantheses around your arguments. It's confusing the compiler to think that (A T T) is one argument.
# cool i got it. thanks!
#
#
# Is there a  way to turn off error highlighting? I find it distracting. Or would you recommend trying to get used to it?
#
# Good question.  I'm not sure that Codio has provided that configuration option, but I don't imagine it would be hard for them to add.  You can ask them directly via the email addresses @754.
#
#
# One potential labeled tree is:
# LNode (        LLeaf [C],        [A],        LLeaf [G]      )
# To clarify -- in this case, when we're trying to compute the sum of all hamming distances, do we add the hamming distance between [C] and [A] as well as [A] and [G]? Thanks!
#
# yes, for this example "all parent-child pairs" are [A], [C] and [A], [G], and parent_child_hamming finds the sum of hamming_distances between all parent-child pairs.
#
#
# it says:
# First failure: parent_child_hamming (LNode (LLeaf [G; T], [A; T], LNode (LLeaf [T; T], [T; T], LLeaf [C; G])))
# i did i by hand and expect to get 4 for this test. I printed my function with it and also got 4. So my only interpretation is that it's not supposed to be 4?
#
# Hmm, you're right that it should be 4. Definitely go to Office Hours and see if you can get a TA to help you--it's hard to do it well over Piazza!
# Isn't this 3? Could we get some clarification for this question?
# Based on my calculation, I got 4. The differences are AT vs. TT (1), GT vs AT (1) and TT vs CG (2) = 4.
# Unfortunately, it is our policy not to give more insight into tests on our submissions server. This is so that students recognize the importance of testing their own code for correctness and not relying on the submission server to test to find bugs for them.
#
#
# For some reason when I try to print anything to the console in dna.ml, nothing gets outputted. Do you know why that is? That's why I can't test my helper functions in dna.ml.
#
# Nevermind, missed the pinned post.
#
#
# What other functions are we also allowed to use?
#
# Any function you think would be useful from the code that's already there :D
# Awesome, thanks!
# Oh, also, are we allowed to use the List module for this one?
# Nope, only code from this assignment. List module is still off limits for now!
#
#
# Hi Sam. I already traced through my code and I really don't understand what is happening wrong.
#
# Here's my tracing:
# A; G; T matches x::y::z::rest -&gt; acids_of_helix (G:T::rest)
# G T A matches x::y::z::rest -&gt; acids_of_helix (T::A::rest)
# T A C matches T::A::C::rest -&gt; Met::(acids of helix rest)
# C C A matches x::y::z::rest -&gt; Gly::(acids of helix rest)
# T C G matches x::y::z::rest -&gt; Ser::(acids_of_helix rest)
# G::[] matches x::[] -&gt; []
# =Met::Gly::Ser::[]
# which is what the answer should come out to.
#
#
# I think it may have something to do with your "let tacmatched = true in" way of going about this problem--it could be that tacmatched is not being properly changed within the recursive calls due to shadowing or something along those lines.
#
# I'd recommend thinking about splitting the problem into two functions--one that goes through and finds the first [T; A; C], and one that analyzes the rest of the list (similar to sublist from HW1).
#
# If you're still having trouble, come to Office Hours! It's much easier to help in person than over Piazza :)
# Edit: ok thanks.
#
# Thank you for providing further detail! I will take a deeper look at it. Before I do so, I want to ask a quick question: is your pattern matching exhaustive? Does it affect your code?
# thank you - realized what I was missing
# Awesome! Glad that it helped. And, sorry for the confusion with the replies (not reading the title right, multiple edits, etc.) :)
#
# no worries, I probably should have formatted it better!
#
#
# I downloaded Firefox and it still wouldn't scroll for me. I also tried Internet Explorer. Maybe it's an issue that is solely on my computer? I will try a school computer later though.
#
# Try doing Shift + PageUp and Shift + PageDown, this worked for me!
# I don't have that option, unfortunately. I have an ASUS Zenbook.
# Have you tried other ways, like highlighting all the text to force it to scroll up? If not, then your solution to use a school computer sounds like your best bet - sorry for the issue!
#
#
# ...
# I know it is reaching this section of code because it is still *repopulating* a LinkedList of objects I draw on the screen
# Hmm ok, so I'm not sure. I would just suggest adding a bunch of print statements to be absolutely sure where you're code is getting, and where it is not. As well as the values of any variables as necessary. Rather than just relying on seeing the objects being drawn.
#
#
# Understandable- I'd compiled and run the code almost compulsively and made numerous zips but I'd gotten rid of my previous snapshots and was about to make a new one before the catastrophic change happened- if I email my TA (I have) and Codio (I have), is there any potential for a extension as the code is recovered? Thank you very much!
#
# Another possibility is that if you haven't touched some of your .class files in the bin folder is that you might be able to decompile that back to the source java code.
#
# You can try emailing cis120@seas.upenn.edu, but  I'm not sure how lenient the professors will be since you had more than two weeks to work on it.
#
# Sorry about that!
# Been trying to decompile but it seems the .class files are from the same version as the code as a whole; I had finished the project and was in fact zipping it (multiple people can back me up on that), and then the deletion happened mere hours before the deadline for code that took the full weekend (and a little bit of which took the full week), so I hope they'll be lenient or at least give me time for Codio to recover my code or maybe recode what I had. We'll see.
#
#
#
#
# it was coming from the draw function of my main game board. it submitted with no issues, and ran in eclipse when I tried it again, but still wouldn't work with codio
#
# It probably should be fine -- you might want to let your TA know during the demo to not run it with Codio but manually/locally.
#
#
# I'm having the same issue, I'm even getting email receipts.
#
# Oh you're right, I did get email receipts. That should mean it submitted successfully right?
# No, the email receipt is just a copy of what happened upon submission. It does not mean your code compiled.
# My first email receipt did say there was an error, but the second+ said the file was submitted successfully? Is this also an error?
# Your email receipt tells what what occurred upon submission -- this could be a successful submission, a compilation error, a timeout, etc. The receipt tells you this.
# Then if I had a successful submission by receipt but my dashboard is stuck on loading, what should I do?
#
#
# it says cannot find symbol, but court is right there:
#
# test/GameTest.java:25: error: cannot find symbol
#         int x = court.getMoveCount();public void testPlayerMoveSimple() {
#         final JFrame frame = new JFrame("test");
#         GameCourt court = new GameCourt(frame);
#         int x = court.getMoveCount();
#         assertEquals(x, 0);
#         court.playerMove(0);
#         assertFalse(court.getPlayer(5, 0) == 0);
#     }
#
# wait, i'm actually stupid
# If I am not mistaken, this was not covered in lecture but was in the notes (not slides).
#
# I see it in the slides here: http://www.seas.upenn.edu/~cis120/current/lectures/lec24.pdf starting on pg. 4 it appears.
#
#
# bruh
#
#
#
# I feel like true or false statements
#
#
#
#
# Constructors are not inherited?
#
# My mistake youre right
# See edit
#
#
# Will there be office hours before the final?
#
# If there are, they will be published on the calendar and/or announced on piazza.
#
#
# Any updates?
#
# Just announced some office hours! Hopefully more TAs will be following suit soon :)
#
#
# oops i meant #2
#
# After connecting the dots, one sees that the answer is indeed D.
#
#
# I still don't understand why it goes to player 1 when it propogates back up instead of going to player 3's target (player 2)
#
# Also, why does it go to the else block right from the if block?
# Take a look at the code for getsIt:
#
# void getsIt(HotPotato potato) throws HotPotato {
# 	System.out.println(name + " gets the potato.");
# 	if (this == thrower) {
# 		System.out.println(name + " throws the potato.");
# 		throw potato;
# 	} else {
# 		try {
# 			System.out.println(name + " passes the potato.");
# 			nextInLine.getsIt(potato);
# 		} catch (HotPotato p) {
# 			System.out.println(name + " catches the potato and throws it.");
# 			throw p;}}}
#
#  Player 3's getsIt() triggers the if statement and not the else statement (because of this line in the code in the original problem  Player.thrower = p3;, which makes this == thrower true. That means it ends up throwing the potato, which eventually starts the propagation up to Player 1 and then Player 2. Originally, Player 3's getsIt() function is called when Player 1's getsIt() function reached nextInLine.getsIt(potato);. Player's 1's getsIt() function was called when Player 2's getsIt() function reached nextInLine.getsIt(potato);.
#
#
# I thought there was a difference because the type argument of tree_fold takes in ('b -&gt; 'a -&gt; 'b -&gt; 'b) for combine, so the third option would be 'a -&gt; 'b -&gt; 'b -&gt; 'b because lacc and racc would eventually evaluate to a 'b type.
#
# Nah
# Third option would still maintain ('b -&gt; 'a -&gt; 'b -&gt; 'b). For third option, "x" would be 'b and "lacc" would be 'a, but, since all that the anonymous function is doing is summing them up, and 'a and 'b are both int in this case, if 'a &amp; 'b are different, and anonymous function does something differently for 'a and 'b types, then third option may not have worked.
#
# However, for this case tho, I think it works. But, please feel free to actually try them out!
#
#
#
# Also part c
#
# First and fourth options are not right - return types.
# Third one implements method wrong. (the input of "applyTo" must go behind, but "prefix", which is the input of "applyTo" comes first in the third option)
#
#
# This is the link to the solutions to the exam I'm talking about:
#
# http://www.seas.upenn.edu/~cis120/current/exams/final-14sp-solutions.pdf
#
# I'm talking about problem 8. There is a grading scheme at the end of the problem. It's the bullet point marked "d."
#
#
# This is because variables used in anonymous inner classes must be marked as final.
#
# For reference, "An anonymous class cannot access local variables in its enclosing scope that are not declared as final or effectively final."
#
#
# Wouldn't it also be that I cannot call frob since it's a method only in J?
#
# This is also correct. I've also revised the instructors' response to include even more things that are wrong. Basically there are just a ton of things wrong with the test as its written haha.
#
#
# Does that means m1, m2, m3 all refers to the same class?
#
# Umm... same class, but different instances if that makes sense.
#
#
# What's the point of using x to mean two different things?
#
# Reference. Thought it would make it easier for you to see how "x" in the code can refer to two different things
#
#
# Since it's a NullPointerException, aren't neither necessary?
#
# NullPointer is a RunTimeException and does not need to be labeled in the method header. That's why the "must" in the statement makes it false.
# Word!
#
#
# But the dynamic type of a0 is B, and B has a defined method for q(). Why would this work in runtime but not compile time?
#
# If something doesn't work in compile time, then it wouldn't even compile, so it wouldn't run. Hence, it makes no sense to claim that something works in runtime but not compiletime.
#
#
# Oh yeah sorry i meant "will it always return null" because of how saved and r are pointing to the same point in the team, so when you do saved = null, doesn't that also make r null? so you always return null?
#
# Ah, I see.
# It'd be helpful if you draw out Java ASM
#
# Here is an example:
# For line
# E r = saved;
# This is what happens:
#
# And for the next line
# saved = null;
# This is what happens:
#
# Thus, when you return "r", you are returning a reference to "Some Obj", not null.
# You were close and it's good that you are considering referential equality!
# I'd say take a look at the lecture on Java ASM.
#
# Hope this helps.
#
#
# where is the static type of the object stored?
#
#
# Is the "static type" of an object even a thing?
# Counter would be the static type, and Decr is the dynamic class, if I'm not mistaken
#
# Oh now I see what ur saying. Yea I have no idea what's going on.
#
#
# But given this specific instance, since ‘a = ‘b = int, couldn’t both answers be true?
#
# Yes, both answers could be true in this specific instance, since it's just adding 3 things together. I'm not sure whether this was acknowledged in 15fa on the final grading.
# However, in the case of the exam, you should always choose the *most* correct answer. The last option is better because the variable names map better to the original f calls ( (f lt) + x + (f rt) ) by maintaining the same order of the computed results (i.e. l, x, r) .
#
#
# Can someone also explain why 1 b is false?
#
# Nvm
#
#
# Why cant Map&lt;Integer, E&gt; work?
#
# Nvm
#
#
# Why wouldn't Iterator&lt;String&gt; work?
#
# TreeSet doesn't implement the Iterator interface - it implements the *Iterable*** interface. Iterable&lt;String&gt; would work.
#
#
# Wouldn't the subclass be able to access the flip method with a super keyword?
# This would allow to change the state of isOn.
#
# ^^^
# Since isOn is private, only the exact class it's in (LightBulb) can access it - even super.isOn wouldn't work here. If you wanted to make isOn accessible to subclasses, we would want to use the "protected" keyword instead of private.
# This is a subtle point! If you have room on your cheat sheet you might copy a table of "Java access modifiers" and what each access modifier allows in terms of visibility to subclasses, packages, the world, etc.
#
#
# But then say it was leveraging INV1 as well, and there could be items in the bag that are ["a" -&gt; 0]. Wouldn't this also be able to work with INV1 because it would return true if bag.get(e) &gt;= 0 as well if these were already in the bag?
#
# If we return bag.containsKey(o) on some o that has value 0, then technically the bag does not semantically contain o--it contains 0 of o. However, bag.containsKey(o) will return true, suggesting that the bag contains a nonzero amount of o, which is false.
#
#
# How do we know this to be true?
#
# This is because this implementation of just returning bag.containsKey(o) assumes that all keys in the bag are positive and are worthy of being counted as being contained. Because it assumes this fact, it's leveraging invariant 2.
# What's stopping us from having a map with values of 0?
#
# Invariant 2 says that a bag will only contain a key if the value of that key is greater than 0. Therefore, we could not have a key with value 0.
#
#
# bump
#
#
#
# please help!
#
# HELP!!!!??!!
#
#
# Yes, but would you ever want to read byte by byte instead?
#
# In general I think it's good practice to use the Buffered versions of I/O because they are more efficient. They don't necessarily read "faster" but they read more input at a time and store it in a buffer, which saves the time it takes to go back and forth between the file to get more input.
# However, sometimes with a BufferedWriter, you have to call a method called flush() to get the output out of the buffer so that it actually gets displayed. If you don't want to deal with the logic of calling flush(), and you want the output to appear right away as it's requested to be written, you might want to use a regular (non-Buffer) writer.
#
#
# Oh bettt you right, thanks!!
#
# Random, but my friend next to me wants to know if you are from DMV area. No pressure to respond if you are busy studying, haha.
# Nope, from the west coast haha
#
#
# Isn't it more so that in java if I write x = "hel" + "lo" and y = "hello" the compiler doesn't know they are the same and thus will create two instances of it on the heap even though .equals returns true?
#
#
#
# Wait oops I meant to post this one
#
# In Java, if s and t are variables of type String such that s == t, then s.equals(t) is guaranteed to return true.
#
# This is the one that I don't understand why it's false
#
# Maybe if s and t were both null, then s.equals(t) would throw a NullPointerException?
# https://piazza.com/class/j6dr9a61zsv5vx?cid=2642
# How would the compiler see that if it only cares about the static type
#
# See instructors' response :)
#
#
# Thanks!
#
# Wait are you sure it's not the other way around?
# It is this way 100%
# Yup. TA confirmed :) &lt;&gt; is structural. You don't see it very often because you usually just do "if x = y then _ else _ " where the inequal case is implemented in the else branch.
# != is what you would do to check for aliasing, etc.
#
#
# Why is the 4th option even correct? I thought J is not an instance of an object, so you cant do J.frib. Also, frib is not a static method.
#
# bump
# Every class is always an instance of Object, since Object is the parent/root class of every other class.
# I think the idea of frob being static/nonstatic might be a typo!
# It's correct because it takes the same object twice, so they are pointing to the same place on the heap - when you change the field of one object, j and j's field both changes. Thus it gets changed to 17, and returns 17, so the test passes.
# Thank you! So was frob supposed to be a static method?
# Yeah I think all the test cases given for that question are wrong because you can't call J.frob like that if frob is not static (I typed it up to make sure) so you're right about not being about to do J.frob
#
#
# Thank you so much! I really appreciate the clarification.
#
#
#
# Just to clarify, we can still do this even if we used some code given as part of hw09 for the mushroom game, right?
#
# The game had no code that a CIS 120 student could not replicate on his or her own. It should be fine.
#
#
# codio is saying I need authorization to dowload my zipped files...
# what does that mean?
#
# thanks
#
# I did that a few days ago. It just asked me for my password. Try that?
#
#
# If a static method is called but from a non-static context, I.e. m is a static method of C, but we create an instance c, and then call c.m() is this also not pushed?
#
# I believe the "this" reference is tied to the constructor of an object, so the "this" reference is pushed when constructing the instance c. Not sure if this answered the question so let me know!
# From Lecture Notes page 248-249 it looks like, yes a "this" is pushed when calling the constructor, but there are also other"this"'s pushed each time a method is called, and its that last "this" used when running the body of the method.
# I'm asking about the second this--when I call c.m(), does Java know that m() is really a static method which will never need "this" and not push it, or because I called m() from c (the instance of C) "this" is pushed, and just never used in the method?
# Non-static invokations of static methods are afaik identical to their corresponding static invokation, so there is still no `this` binding created in the stack.
#
#
# should have my game project grade been posted yet?
#
# @4229
#
# If it’s not emailed and posted by tonight you need to reach out to your TA!
# ^ the deadline is actually tonight at midnight!
# thanks!
#
#
# Is there a grade distribution graphic for the final similar to the other midterms?
#
#
# There will not be, but you can email the professors to discuss your grade if you would like. Happy holidays and enjoy your break!!
#
#
# Will there be separate statistics released regarding grade distribution, for both course grades and final exam grades?
#
# Final exam statistics are here: @4259
# So, is that a no for the grading distribution/curve scale?
# Yea ¯\_(ツ)_/¯ I don’t think the curve will be available.If you’d like to discuss your exam grade or final grade with the professors, they’re very open to your emails c:

# %%
myDB.execute("SELECT * FROM CIS120")
row = myDB.fetchall()
while row is not None:
  print(row)
  row = myDB.fetchone()
# Out:
# ((7, 'Switching Recitations', 'logistics', 'I wanted to switch my recitation from 212 to 218 in order to sign up for another class. I filled out the form on the CIS 120 website. Am I also allowed to switch it in PennInTouch so that I can sign up for the other course?\n\nThanks,\nJosh Cohen', '\nPlease do not make the change yourself on PennInTouch. \xa0We will contact you once the change has been made. \xa0(If you try to enact the change yourself on PennInTouch, you might accidentally be dropped from the class due to not having a recitation. \xa0The class is full, so you would not be able to re-register.)', 0, 0, 0), (7, 'Switching Recitations', 'logistics', "Professor,\nThanks for letting me know. Unfortunately, since I hadn't heard anything and I wanted to make sure I got the class materials/homework for the other class, I switched the recitations on Pennintouch. I specifically chose 218 since it was listed on the lecture notes as needing more students. Is there any way I can keep this recitation so I don't have to switch out of the other class? If not, I will switch back to my original recitation in PennInTouch and temporarily drop the other class.\xa0\nThanks for all your help and I'm really sorry for all the trouble.\nJosh", "\nNo worries -- if everything worked out, then there's no need to do anything else. \xa0 You're good to go. \xa0(The problem is that PinnInTouch can sometimes kick you out of the class if you don't have the associated lab section, but if you are registered for both a lab section and the lecture, you're fine.)", 0, 1, 0), (8, 'Homework 01 on Codio', 'hw1', 'Hi\xa0Professor Sheth,\n\nI just saw the homework 01 folder in Codio, and was wondering whether we need to complete it before or after our first class. Could you please help me out?', "\nHi Lakshay.\n\nNo, you don't need to do it before the first class. It's due in just under 2 weeks on September 12.\n\nWe'll talk about this (and other logistics) in class today. You can also find the schedule and syllabus on the class website -\xa0https://www.seas.upenn.edu/~cis120/current/lectures.shtml\n\nSee you in a few hours!", 0, 0, 0), (11, 'Final Exam Date', 'logistics', 'Hi,\nThis may be my error, but I do not see a date for the final exam posted on the CIS 120 page. Also, the Canvas page for this class does not appear to have been published.\nAre these two resources unavailable right now?\n\nThanks', '\n1) Yup, we do not use Canvas for this class. The information you need for the class can be found here:\xa0https://www.seas.upenn.edu/~cis120/current/.\n\n2) We are working on the final exam date right now (it is scheduled by the registrar) to make sure that both sections take it at the same time. We will let you know when it is confirmed.', 0, 0, 1), (14, 'Use of documentation allowed?', 'hw1', 'Hi, thanks for the quick answer. I just had a quick follow up question, since I thought that that part of the "rules" only applied to the first part of the assignment. The part I am talking about is the one starting from "The remaining exercises provide practice with lists and recursion.". I thought that that implied that we could use the List functions, but now that I think about it again it does seem like my assumption was made way too fast.\n\nBut, just for the record - Something like this would be disallowed since I\'m using List.length, List.hd, List.tl and String.sub/String.length, right?\nlet rec join (separator: string) (l: string list) : string =\n  let rec pushstring (s : string) (ll:string list) : string =\n    if List.length ll == 0 then String.sub s 0 ((String.length s)-(String.length separator)) else\n    pushstring (s^(List.hd ll)^separator) (List.tl ll)\n  in pushstring "" l', '\nCorrect. This would not earn credit. Since there has only been one lecture, I imagine the professors haven\'t covered the topic necessary to complete the second half of the assignment. However, if you went to self-teach, I would focus on the part of the lecture notes under  ...
