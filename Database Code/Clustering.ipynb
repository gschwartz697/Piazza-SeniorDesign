# %%
import csv

# initializing the titles and rows list 
fields = [] 
rows = [] 
raw_questions = []

filename = 'contributions.csv'
# reading csv file 
with open(filename, 'r', encoding="utf8") as csvfile: 
    # creating a csv reader object 
    csvreader = csv.reader(csvfile) 
      
    # extracting field names through first row 
    fields = next(csvreader) 
  
    # extracting each data row one by one 
    for row in csvreader: 
        rows.append(row) 

    curr_question = ""
    curr_text = ""
    curr_topic = ""
    curr_folder = ""
    curr_answer = ""
    curr_number = 0
    curr_follow_up = 0
    endorsed = 0
    
    # This will help us take the most recent version because it always comes first
    already_filled = 0
    for row in rows[:]: 
        # parsing each column of a row 
        for col,field in zip(row, fields): 
            if(field == "Post Number" and curr_number != int(col)):
                if(curr_question != "" and curr_answer != ""):
                    raw_questions.append(curr_question)
                curr_number = int(col)
                curr_follow_up = 0
                curr_question = ""
                already_filled = 0
                curr_answer = ""
                curr_topic = ""
                endorsed = 0
                
            elif(field == "Submission HTML Removed"): #the question could also be in subject
                curr_text = col
                
            elif(field == "Subject"): #We want to check if this is actually the question eventaully
                curr_topic = col
                
            elif(field == "Folders"):
                curr_folder = col
                
            elif(field == "Endorsed by Instructor"):
                if(col == "TRUE"):
                    endorsed = 1
                else:
                    endorsed = 0
            elif(field == "Part of Post"):
                if(col == "started_off_question"):
                    if(already_filled == 0):
                        curr_question = curr_text
                    already_filled = 0
                elif(col == "updated_question"):
                    # update question entry to post and follow up numbers
                    if(already_filled == 0):
                        curr_question = curr_text
                        already_filled = 1
                        
                elif(col == "updated_i_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                    endorsed = 1
                elif(col == "started_off_i_answer"):
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                    already_filled = 0
                    endorsed = 1
                    
                elif(col == "updated_s_answer"):
                    # update last entry to the post and follow up number
                    # what if it was appended? how do we update just the end?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                        already_filled = 1
                elif(col == "started_off_s_answer"):
                    # append to answer - if it was previously endorsed and were appending should we keep it endorsed?
                    if(already_filled == 0):
                        curr_answer = curr_answer + "\n" + curr_text
                    already_filled = 0
                    
                elif(col == "followup"):
                    # new entry for the new followup question 
                    if(curr_question != ""):
                        raw_questions.append(curr_question)
                        curr_question = ""
                        curr_answer = ""
                        endorsed = 0
                        already_filled = 0
                        
                    curr_follow_up = curr_follow_up + 1
                    curr_question = curr_text
                elif(col == "reply_to_followup"):
                    curr_answer = curr_answer + "\n" + curr_text
                    
num = 0
for i in raw_questions:
    print(num)
    print(i)
    print('\n')
    num = num+1

#myDB.close()
# Out:
# 0
# Hi, where is the 6th floor bump space?
#
#
#
# 1
# Is there a preliminary date and time for the final yet?
#
#
# 2
# Is this going to be the case every week? Or was this just for this week? I wouldn't want to go to the wrong location.
#
#
# 3
# I just registered for the course, can the last two weeks of slides be posted to canvas? Thank you!!
#
#
# 4
# Got it. Also, have recitations been assigned yet?
#
#
# 5
# Will Question 3 just be graded by the TAs looking at our code? What we print out shouldn't matter right?
#
#
# 6
# When asking for a DFS and BFS order, can we assume there are multiple correct answers depending on your implementation, because I believe that is the case.  Or sit there some arbitrary rule we should be following related to ordering?
#
#
# 7
# For question 2, are we allowed to designate which actors are mainstream/indie, or is that already determined? Also, should we answer qualitatively/descriptively, or more quantitatively by referencing implementation/code, etc.?
#
#
# 8
# What should we use as the source node in steps 2 and 3 when we have to run BFS and DFS?
#
# "Implement the BFS algorithm and run it on the data that you loaded in the previous step."
# "Implement the DFS algorithm and run it on the data that you loaded in the previous step."
#
#
# 9
# For BFS should we implement our own queue?
#
#
# 10
# Do you have a preference as to how we implement it? For example, priority queue vs linked list implementation?
#
# Getting different answers for both implementations.
#
#
# 11
# Does the "distance" between two nodes refer to the length of the shortest path between the nodes?
#
#
# 12
# So if we had a graph like: a-&gt;b-&gt;c-&gt;d, is 'd' a distance of 3 away from 'a'?
#
#
# 13
# Should these algorithms terminate when they have visited all the nodes in the same connected component as the start node? Or should they then choose an arbitrary node in another component and repeat the process?
#
#
# 14
# It looks like CheckStyle is no longer available on the marketplace. Is there any resources for installing it manually?
#
#
# 15
# The 'From the update site' also do not work
#
#
# 16
# I have the flu so I wasn't able to come to class today. Is there anyway I can make up the material I missed?
#
#
# 17
# Will there be a recitation today?
#
#
#
# 18
# We don't have to mention what data structures, or other implementation details (instance variables, classes, etc.) when we discuss our algorithm, right?
#
#
# 19
# Should we pass the file in as an argument before running the program or should we assume the file name will be the same and can just hardcode it?
#
#
# 20
# I signed into the class just now.
#
# Are there any important logistics? and are there any ways such as slides of the class so that we could catch up with the materials that was covered until now?
#
#
# 21
# How should we be reading the edges in the file? For example, starting from the upper left hand corner, is  0-10 (reading horizontally) an edge or 0-90 (reading vertically)?
#
#
# 22
# So if the first four numbers on the first line were: 0 1 2 3, do I assume that edges are 0-1 and 2-3 or is it 0-1, 1-2, 2-3?
#
#
# 23
# If we modify our BFS and DFS algorithms from #2 and #3 to answer the analysis questions in #4, what should be included in our final submission -- unmodified BFS/DFS or whatever methods we used to answer #4?
#
#
# 24
# For 4.c it asks us to count the frontiers depending on which node we start at. I was wondering if we should call just the starting node a frontier. Usually it is referred to as the 0th frontier.
#
#
# 25
# This question is basically asking to find an algorithm that can tell if the graph is bipartite right? We should be able to separate the graph into two groups, but it should not be possible to label one of those groups as mainstream or indie right?
#
#
# 26
# But there shouldn't be any way to tell which group is which right?
#
#
# 27
# Should our program be generalized (i.e. able to model any text file of nodes and edges with the one-pair-per-line format) or may it be specific to the facebook-combined.txt file?
#
# (e.g. should the program have to determine number of nodes in the graph, or can I hardcode in that its 4039)
#
#
# 28
# Do we have to proof that our algorithm works for question two (i.e. our algorithm always returns mainstream/indie classification sets if they are possible, and always fails if impossible), or is giving the algorithm enough?
#
#
# 29
# For question 1, I was wondering what it means to show the order of the nodes visited. If we have visited a node x before, and we revisit the node, but since we know the node has been added to the order already,  in our answer do we need to show that we visit this node again?
#
#
# 30
# What is a frontier/step?  Does considering/touching a node count as a step? Does revisiting a node after it has been visited count as a step?
#
#
# 31
# How do we count the number of frontiers if a graph has more than one connected component?
#
#
# 32
# Are we allowed to hardcode how many nodes there are?
#
#
# 33
# For both DFS and BFS, I am taking in a source as the input, and running the search using the source as the starting point. In the methods, I am storing the nodes and their distance from the source node in a map, and returning this map.
#
# If the nodes are not within the same connected component as the source, how should I account for the distance? Is it necessary that I do so or can I just have a map that explores all nodes with paths from the source?
#
#
# 34
# I had to restart my computer and when I went to reopen Eclipse, I'm getting errors on every line. How should I go about fixing this?
#
#
#
#
# 35
# What does the order of nodes visited mean in context of DFS? Is a node denoted as 'visited' when it is originally added to the stack or when it is added to the list of finished nodes?
#
#
# 36
# Do we count the number itself?
#
#
# 37
# How many homeworks in total will there be in this class including the final project?
#
#
# 38
# Will we be graded on efficient runtime? My DFS runs for a few seconds.
#
#
# 39
# Where is active learning?
#
#
# 40
# Will there be recitation tomorrow?
#
#
# 41
# I can't figure out why I'm not getting the option to create a new JUnit test case for a class. I definitely have the JUnit 4 library, and I've tried re-adding it multiple times. If someone has had this issue before and can offer some insight, I'd really appreciate it.
#
#
# 42
# I'm very confused about this question.  There is no logical difference between mainstream and indie, thus for any possible designation of mainstream and indie, there is another possible  designation with the type of each actor flipped.  Unless the type of one actor is given initially, clearly no conclusions can be made, and that's O(0) time since there's no algorithm.  Is there something I'm missing?
#
#
# 43
# I was wondering if we need to return anything in BFS or DFS function? Perhaps an iteratble or print anything in the function? Thanks.
#
#
# 44
# can a ta confirm?
#
#
# 45
# Are we implementing a class with a main function where we do
#  java Main
# to run or is a class that will be instantiated and functions will be called?
#
#
# 46
# Why is this necessary?
#
#
# 47
# Is it the case that each actor only has one rivalry? Or can an actor have many rivalries, and can her rivals also have other rivals? Because if it's the second case and an actor is really mean and has rivalries with every other actor, but some of those actors have rivalries with each other, dividing them is impossible. Thank you!
#
#
# 48
# Just want to clarify - every rivalry must be between a mainstream actor and an indie actor? i.e. there are no rivalries within each type?
#
# Thanks!
#
#
# 49
# If it asks why the graph is connected is it asking how do you know or why does it make sense that the graph is connected(or not)?
#
#
# 50
# Hi quick question! Is the number of nodes in the test file equal to 3957? Can someone confirm that? Thanks!
#
#
# 51
# For Q1, parts b and c, does it suffice to write a sequence of nodes in the order that they're visited (e.g. a,c,d,b,f,e ...) or should we show the queue and finished sequences at every step?
#
#
# 52
# Can I put my answers to the programming questions in the same file as the theory questions?
#
#
# 53
# Do you care how we implement an adjacency list? If I used a map from a key to a list of values is that okay? Thank you
#
#
# 54
# For question 4c is it sufficient to use one rather than both algorithms? Finding the steps (which I am interpreting as the "longest path" between vertices) is much simpler if using DFS.
#
#
# 55
# Hi Allison! Thank you for your response. I guess I am a little confused as to what a "step" is.
# For example, in a graph a-b-c, a-d-e, would the total steps be equal to the depth of the graph, i.e. three?
#
#
# 56
# The BFS algorithm itself explicitly only gives you an array of elements, ordered by distance, but does not actually tell you what the distance of a particular node is to the start node. Should we add a field in our algorithm to also return the distance of each node, along with where it is returned in the resulting array. Basically, what I'm saying is should our BFS algorithm return a tuple array, where each tuple consits of the node/distance, or instead should we make a separate method to calculate the distance between any two given nodes?
#
#
# 57
# But would't adding print statements make the program run in severely more time? Which would probably make comparing the two implementations' efficiency (the extra credit part) unreliable?
#
#
# 58
# In Q2, let's say we have the following list:
# 1. A-B (A and B are rivals)
# 2. C-D (C and D are rivals)
# Given this information, we know that A and B belong to separate categories. Similarly, C and D belong to separate categories. Should our algorithm tell us the relationship between A and C, B and C, A and D, and B and D as well? Because unless we're given the relationship between at least one node in 1 and one node in 2, we cannot conclusively tell the relationship between the nodes in 1 and 2.
#
#
# 59
# how do i do this? i can't figure out if i should be using prewritten code from online or if i should figure out some way to read in the text file myself. is there some function in java that i can use to do this more easily? should i create a new datatype or can i just create a 2d matrix? (i know this was a bunch of questions in one but i am very confused about how to approach this)
#
#
# 60
# building the adjacency matrix makes a lot more sense now but i'm still unsure about what to do to read in the files (is there a java command?)
#
#
#
# 61
# What is BFS/DFS supposed to do in the case of a disconnected graph? Should I be traversing every component every time, or is it alright if it just traverses the component containing the start node?
#
#
# 62
# In my adjacency list graph implementation, if I start the BFS at node 1:
# The neighbors of 1 are as followed:
# 1: 0, 194, 322, 133, 73, 299, 236, 48, 53, 54, 119, 88, 280, 346, 315, 92, 126
#
# So, my implementation next explores the neighbors of 0, then the neighbors of 194, then the neighbors of 322 etc
#
# Should I be exploring the neighbors of 0, then the neighbors of 48, then the neighbors of 53, etc so that the neighbors of 1 are explored in numeric order?
#
#
# 63
# I believe that my variables and class names are fairly well named so that any reader should be able to understand the intuition based on prior knowledge; there is no complicated logic or obscure language features. Are the javadocs absolutely mandatory?
#
#
# 64
# Where can we learn about javadoc-style comments and what exactly is required of us in terms of comments?
#
#
# 65
# Just confirming - we will have lecture as usual today since classes start at 12pm?
#
#
# 66
# Are we allowed to use Java 8 for this assignment?
#
#
# 67
# How is our program supposed to deal with vertices which have no edges? Since our input file takes in pairs of vertices, do we have to deal with this case? Also can we assume that there will be vertices from 0 to n if vertex n is there? For example, that if we have some node 10, that there will be nodes from 0 to 9 included in the input text? Overall, will our program be tested on inputs other than the facebook_combined.txt input file?
#
#
# 68
# 12pm is midnight correct?
#
#
# 69
# Will HW2 have any extra credit opportunity?
#
#
# 70
# Does the textbook generally cover the material in the class well?
#
#
# 71
# For the designation of the pair of actors, can we store values associated to the actors? For example, if the input is pair A-&gt; B and pair A-&gt; C, can we store the value of A (indie or mainstream) so that it is recognized if it appears later in the list of the r pairs?
#
#
# 72
# Do we need to prove algorithm correctness and running time for Q2?
#
#
# 73
# In our dfs implementation do we have to return anything or can it be a void function? What if we print out the order in which the vertices are visted?
#
#
# 74
# Can the graph be considered as one component?
#
#
# 75
# This basically refers to the number of levels in the graph right?
#
#
# 76
# When implementing BFS, do we have to choose a different random start node each time the program is run?
#
#
# 77
# I'm having problems running my bfs to see if the network is connected– when I hit run it says "java.io.IOException: Stream closed" (with a bunch of other stuff below)– does anyone know how to solve this?
#
#
# 78
#
#
#
#  For Extra Credit, use the other one and compare how long the following take (in terms of time – seconds, milliseconds, etc.)
# Do we have to code it the different way as well or just analyze it?
#
#
#
#
#
# 79
# If the graph is 1-&gt; 2 and we run bfs (with the start node being 1). Would the number of frontiers be 1 or 2?
#
#
# 80
# what about 1-&gt; 2 and 3-&gt; 4 and the start node is 1.. It should be 3 right?
#
#
# 81
# Can we assume that the inputs will have nodes that have a max value of let's say 5000? Knowing this can reduce our run time
#
#
# 82
# Do we have to do a java docs style comment when we declare private instance variables even if the names are self explanatory? Or should we just write one big java docs style comment above all the declarations explaining what each one is?
#
#
# 83
# Is it okay if the readme is included with the java classes? I wrote it in eclipse with the rest of my classes.
#
#
# 84
# When submitting our homework should we submit a read_me explaining our code and how to run it and a word doc explaining how we used the code to find the answers? In office hours yesterday, there was mention of submitting a word doc about how you manipulated the code. Thanks!
#
#
# 85
# Hello! I am really struggling with getting the BFS to run up to a specific depth. Can someone give me a hint as to how to continue? Thank you so much.
#
# LinkedList&lt;Integer&gt; queue = new LinkedList&lt;Integer&gt;();LinkedList&lt;Integer&gt; bfs = new LinkedList&lt;Integer&gt;();	int numNodes = 0; //this is the num elements in the queue 	boolean[] marked = new boolean[size];	marked[start] = true;	queue.add(start);	numNodes++;		while (!queue.isEmpty()) {	numNodes--;	int curr = queue.pollFirst();	bfs.add(curr);	HashSet&lt;Integer&gt; neighb = g.get(curr);	LinkedList&lt;Integer&gt; neighborSet = new LinkedList&lt;Integer&gt;();	neighborSet.addAll(neighb);	while (!neighborSet.isEmpty()) {		int friend = neighborSet.pollFirst();		if (!marked[friend]) {			if (numNodes &gt; 0) {				queue.add(friend);			}		else {			marked[friend] = true;			bfs.add(friend);		}	}}		}		return bfs;	}
#
#
#
# 86
# Oh thank you that makes so much more sense!
#
#
# 87
# Are there some sample values for nodes and their corresponding depths that we can use to test our code to find depth? I can't tell right now if my program is working correctly.
#
#
# 88
# When you say to explain how to run the program, do you mean how to run BFS and DFS? Or how to get the answers to the questions? My bfs and dfs methods are void and don't print anything. Should I fix it so that it does print the order that it is visited?
#
#
# 89
# Are there any lecture notes available for this course. I couldn't find any on the website.
#
#
# 90
# Will it be a problem if my code reads the facebook txt file using the complete file path of my computer? It doesn't seem to work with just facebook_combined.txt
#
#
# 91
# I fixed it, my txt was within the src file and that wasn't working.
#
#
# 92
# Two of my abstract classes have multiple subclasses that implement functions of the same exact same name. So for instance, class Foo may have a method named Bar, which is implemented by Baz1, Baz2, and Baz3; that is, Baz1 implements Bar, Baz2 implements Bar, and Baz3 implements Bar. Is it necessary to add a comment for Bar in each of Foo, Baz1, Baz2, and Baz3, or can I write javadocs for just the Bar in Foo?
#
# Also, are javadocs necessary for constructors, getters, and setters (e.g. if we were working with a Tree class, should we comment on getRootNode)?
#
#
# 93
# For homework 1 I wrote the program in Eclipse but when I submitted it and opened it again on the homework site where I submitted it, it opened with Dr. java on my Mac and not Eclipse. I was wondering if this would be a problem when grading? Will it be viewable in eclipse?
#
#
# 94
# We just have to show the order in which the vertices are visited, right? Is there a need to show our working?
#
#
# 95
# When it asks for distance is it asking for the number of edges between them? If not, what is the metric for distance here?
#
#
# 96
# Should we zip up the entire project folder, the entire src file, or just the .java files, along with the writeups?
#
#
# 97
# I'm trying to resubmit my assignment but the new file adds a "-1" to the end of my filename, since I already submitted a previous file with the same name. Will this be a problem?
#
#
# 98
# Hi! I had submitted my homework before but just resubmitted it. For some reason when I resubmit my file becomes renamed jianingw-1.zip instead of jianingw.zip (my pennkey.) Is this an issue? Sorry!
#
#
# 99
# When I try to run this program with the following arguments, the program stops running before it does all 100 trials and the visual representation doesn't show up. Any idea why? I increased the number of classes argument by 1 and kept the other arguments the same.
#
# simulator = new SchellingSimulator(1, 3, (int) (50 * 50 * 0.92), 4, 50, 50);
#
#
#
# 100
# When it asks for an example, how many nodes should it have at minimum?
# I mean if I have two nodes, is that enough?
#
#
# 101
# Where is the place called active learning?
#
#
# 102
# Could you explain what the facebook.txt file represents? What are the nodes and what are the edges? What does the numbers mean?
#
#
# 103
# if the line is
# 1 2 3
#
# is there a edge between 1 2 and 2 3?
#
#
# 104
# Two questions:
#
# 1). I wanted to run an experiment that needs to consider an increasing number of populations (ranging from 3-5 populations instead of 2 like the examples you gave in the file), but it doesn't open the visualizer or finish any of the tests. I saw @110, but do you have any suggestions for this in particular that might help some more?
#
# 2). Could you explain what the seed number does and how a lower/higher number might change my tests?
#
#
# 105
# Is there a practice exam for the upcoming midterm?
#
#
# 106
# Hi, I've had an extremely busy week and was unable to get HW1 in on time. I was planning on finishing it by the late deadline but I realized just today that I completely screwed up the deadline; I thought it was due at midnight (read 12am instead of 12pm) today instead of noon! Is there any way I can still get some credit for the assignment?? Really sorry about this, I realize it's completely my own fault for misreading the late deadline!
#
#
# 107
# When implementing the bfs and printing our the remove elements from the queue
#
# There should be always 4039 outputs regardless of what target node we select right?
#
#
# 108
# Just a clarification: should we give the shortest paths from every node to every other node or the shortest paths from s to every other node?
#
#
# 109
# Professor Sheth,
#
# My apologies, I thought I had until 12 am to hand in the assignment not 12 pm. Is there any way I am still able to hand in the assignment? Or at this point is too late.
#
# Thank you
# Bram Bruno
#
#
# 110
# The default code provided doesn't go past trial 738 -- is this intended?
#
#
# 111
# Is there a scheduled date and time for the final exam?
#
#
# 112
# The book only defines a violation of the triadic closure principle. If a node does not have two strong edges coming out of it, and therefore cannot violate the principle, does it then fulfill the principle by default?
#
#
# 113
# For part 1, question 1 what is meant by "the start time of B must be less than or equal to the finish time of A". What is the start time? Like is it when DFS reaches node B? Is the finish time the time when A is taken off the recursive stack (if DFS is recursively implemented)? I am just confused by the wording of this question.
#
#
# 114
# I'm confused about what we are being asked to do. Are we just adjusting parameters when making a new Schelling object to test out a certain segmentation?
#
# For example, if I wanted to see how people in different economical classes segment, would I just be changing the class size? Or would I have to make more adjustments to the program?
#
#
#
#
# 115
# Should we be using real data or just inferences/ideas about a specific population to change the parameters?
#
#
# 116
# Should we write a topo sort algo and apply it to the graph or can we do it by hand?
#
#
# 117
# I've been trying to play around with changing some parameters in SchellingVisualizer, but no matter what I do, if I bump the "minimum Neighbors like me" number to anything above 3, the program can never even come close to finishing all 100 trials--it often stops within the first 10, sometimes not even going through the first one. I've tried different seeds, making the board smaller/filling it with far fewer people, and nothing seems to work.
#
# I understand that the code isn't really "stopping", as it's just trying to make everyone happy and having a hard time (@121 @110). But I'm wondering if there's any way to make it complete the trials, or if we should avoid doing analysis on minNeighbors.
#
#
# 118
# The question says that when we have a choice, we should go for the node that appears earlier in the alphabet. Is this talking about when we are implementing DFS? Or how the final outcome should look like?
#
# For example, should we start our DFS with $$m$$ because it goes earlier in the alphabet? Or start our DFS with $$z$$ so that the final outcome puts $$z$$ towards the end, like in the alphabet?
#
#
# 119
# I was wondering how complex the question we would like to answer would need to be. I was originally thinking of increasing the class size to 4 and comparing the number of segmented chunks for every run using a different number for minNeighbors. I wasn't sure if this would be sufficient enough.
#
# Another idea I had was to have a different minNeighbors value for different classes. So class 1 would need 3 like people, class 2 4 people, etc. This idea would require much more to implement.
#
# Would either of these ideas be enough for the project?
#
#
# 120
# Are we supposed to just write a list in topo order?
#
#
# 121
# Yes  question 2
# What I'm asking is: for the ordering of vertices, are we supposed to only write the nodes in descending finish order?
#
#
# 122
# Is it ok if only one edge has a negative weight?
#
#
# 123
# Is a node considered finished if it has been seen twice by DFS? For example, in the picture I drew below(assuming we start at C) A can possibly be seen twice before D's other's neighbors have ever been seen because of the cycle. Or would it not be finished because B hasn't been seen yet and it's a descendent of A?
#
#
# 124
# Just a clarification - Till what topic will the midterm be on?
#
#
# 125
# Are we to assume that in the directed graph G, the only node that has a path to node B is node A?
#
#
# 126
# Would it be possible to post the link to the Schelling Model Simulator website we looked at in class?
#
#
# 127
# What exactly are we graphing when hw 2 says to "accompany them with a graph (line, chart, bar, pie) supporting your case"?
#
# Are we supposed to make a graph based on the average homophily ratio for class 1 and 2 for all trials?
#
#
#
# 128
# Because of the modification of our algorithm should we start at node m because it is the smallest letter
#
#
# 129
# So I was messing around with the simulator for part 2, and changing the number of groups. I realized that when I increased the number of groups, the simulator wouldn't get through all 100 trials and would get stuck in an infinite loop within the simulate function. However, what I really thought was interesting is that it seems to get stuck on the same trial number each time I run the program. But if it's actually randomly populating the grid each time simulate runs, shouldn't it also randomly get stuck on a certain trial?
#
#
# 130
# How do we run the program? When I try to run it, Eclipse returns a message that says "Editor does not contain a main type" even though the main method is very obviously declared in it.
#
#
#
#
# 131
# Can we assume that all start and finish times are distinct? (In what situations would this not be the case?)
#
#
# 132
#  simulator = new SchellingSimulator(100, 3, 20000, 4, 150, 150);
# How come I only see two colors yellow and blue? The black denotes empty spaces right?
#
#
# 133
# Can you give a couple of examples of what kind of segregations we can do? Like I remember the professor giving certain examples in class. However, I don't remember those examples.
#
#
# 134
# If we are testing out many different seed numbers and populations etc to validate our hypothesis would explaining our observations in those different cases be enough?
#
#
# 135
# What did you mean by "setting up the experiment correctly"? Is there an objective way to go about setting up the experiment correctly?
#
#
# 136
# Hi, I'm not really sure what to do for the coding portion of the homework. When it wants us to test a sociological question and expand parameters, does it mean that we should modify one of the parameters passed into the SchellingSimulator object or should we create a new parameter and modify all of the methods to take into account the effect of the new parameter? If it is the latter, I'm not really sure how I should modify the other methods.
#
#
# 137
# In problem #5 (exercise 3.7 from chapter 3), if a node A has a strong tie to B and a strong tie to C, but the path between B and C consists of two edges instead of one weak or strong edge, does node A still satisfy the strong triadic closure property?
#
#
# 138
# Should we only be turning in the two PDF files (theory and experiment), or should we turn in code as well?
#
#
# 139
# Where will you be holding the office hours?
#
#
# 140
# For part 1, I have hand-drawn my graphs for question 4. If I am typing it up with latex can I upload these images to my document instead of making them on the computer?
#
#
# 141
# In the homework for part 1, question 3 says to show the shortest path cost using Djikstra's– does this mean we have to somehow indicate the iterations in a diagram or can we just write the shortest path for each node by calculating it ourselves?
#
#
# 142
# If one of our axes starts from a certain value that's not zero, is it okay to just start our axis from there?
#
#
# 143
# The textbook I bought and the pdf posted for the textbook have a different 3.7-3. Which should we solve?
#
#
# 144
# I think that's figure 3.21, instead of 3.22. If we already did the question based on the online textbook, will we have to redo the problem?
#
#
# 145
# For a review on everything we learnt about the internet in class what book/chapters of the book can I look up?
#
#
# 146
# What if we wanted to watch the full video that we saw the start of in class?
#
#
# 147
# Is it due at midnight or noon?
#
#
# 148
# Is it okay if our directed graph has paralell edges? It doesn't say anywhere that this isn't possible.
#
#
# 149
# Or do we need separate files for them?
#
#
# 150
# For my experimenting I decided to increase the total area but leave the population amount the same. I found that at first the Homophily ratio began to decrease which made sense since cliques began to spread out and there were a larger amount of unlike items compared to like items for any given person. But eventually Homophily ratio began to increase again, which doesn't make much sense to me especially since Swap said in a post that empty spots count as unlike neighbours right now. Any idea on what's going on?
#
#
# 151
# Hello! I was wondering how much is expected of us in terms of writing up answers. For some questions, I have 2-3 sentences, while for one like the one below, I have a paragraph. Would this constitute a thorough answer? Thank you!
#
#  Explain why Dijkstra’s works correctly in certain cases and incorrectly in others. (5 points)
#
# Dijkstra’s algorithm consistently works if edge weights are not negative. However, if edge weights are negative, the properties of a greedy algorithm can sway the correctness of the shortest path. Specifically, the algorithm chooses the best choice “at the moment”. Thus, it does not take any measures that would indicate that adding an edge to the graph could reduce the length of the path. However, in the case of graphs with negative edge weights, a negative weight could change the path length of nodes already marked visited.
#
#
#
# 152
# Also, for problem 3, I solved it before seeing the piazza post, and merely showed the path:
# S(0), s-&gt;t (3), t -&gt; x(9), s-&gt;y(5), y-&gt;z(11)
#
# is this sufficient?
#
#
# 153
# I think I am misunderstanding Dijkstra's algorithm because I don't see any issue with negative edge weights. What determines if a node is "finished" by this algorithm?
#
#
# 154
# What are some of the parameters we can modify in SchellingSimulator.java?
#
#
# 155
# My hw1 does not have any comments, yet I got some points off. How can I see what I did wrong? Thank you!
#
#
# 156
# Sorry missed class when the regrade policy was discussed...Could someone briefly explain the regrade policy?
#
#
# 157
# For part 2 I think I misinterpreted the question. I thought we were supposed to modify the actual model instead of just expanding the set of parameters. I modified the program to see if segregation still occurs as much if instead of considering the nodes that are directly up, down, left, right, and diagonal to be a neighbor, we just considered diagonal nodes as neighbors. Is what I did wrong and should I redo this part of the assignment?
#
#
# 158
# If we don't use Schelling Visualizer in our experimentation, is it ok to only submit our write up and the Schelling Simulator code?
#
#
# 159
# Both canvas and Piazza says office hours are supposed to be happening right now at WTH. There is currently no TA here.
#
#
# 160
# Where are Natalia's office hours held? I cant find the location anywhere.
#
#
# 161
# I'm a little uncertain about what the HW means by a 'sociological question'. Does this mean it has to be some real-world phenomenon? For example, something like "How might  the urban geography of Greece change with the influx of new immigrants?" or "How does an increase in people's tolerance affect the homeophilly?"
#
#
# 162
# If we change the numClasses parameter in SchellingSimulator to a different number (say 5), would we have to change anything else to make the code work?  I've been trying to change the number of classes to 5 but am not sure what else I would have to modify besides the numClasses parameter.
#
#
# 163
# Is there a built-in way to change the size of the population for each class (ie, class A has 10 people, B has 20, C has 30)? Can I implement this myself within populate()
#
#
# 164
# Where in Weiss Tech House is today's office hours?
#
#
# 165
# Is the lowest homework grade removed from the final grade?
#
#
# 166
# I edited the code in SchellingSimluator to include a third class of people and edited the paint function in SchellingVisualizer to have a third color, but it still results in a graph of all yellow and blue. Is there something I'm missing in the code?
#
#
# 167
# Is there a way to change the population size for each class (for it's not a 50/50 split)?
#
#
# 168
# I was reading my feedback from homework 1 and it said the PDF file was unable to be opened out of the zip. What should I do about that? Is there a specific way to attach it that ensures it can be opened? Can I submit the regrade for that reason?
#
#
# 169
# Do we have to submit the code if we modified the file?
#
#
# 170
# Also, can we attach images of the visualizer as part of our explanation?
#
#
# 171
# I wanted to know if this counted as something to experiment--I wanted to test a different definition of happiness (to include people a distance of 2 or 4 away instead of just 1 away) with different minNeighbor thresholds. This doesn't really require me to change much code (only the isHappy() function), but does this count as a valid experiment?
#
#
# 172
# What's the late policy for this homework? How long can we hand it in late after the deadline? How many points would be deducted?
#
#
# 173
# Is it necessary to zip up the files in one folder? Or can we submit the java files and the write up separately? Do we need a ReadMe for the java files?
#
#
# 174
# Anyone know how I can decrease the number of grey pixels?
#
#
# 175
# Or how to get 4 classes to work with a threshold of 4
#
#
# 176
# The question does not mention anything about which node DFS starts on. We don't assume that DFS starts at node A right?
#
#
# 177
# Can someone explain what the average homophily ratio given to us through the simulator represents?
#
#
# 178
# Do the Schelling programs count 8 neighbors as the max, or are they only counting the adjacent ones (so maximum of 4 like neighbors?)
#
#
# 179
# Hi. Here is my sociological question: Why are neighborhoods with more access to public transportation populated with residents of lower income? (I’m thinking about how NYC city planner Robert Moses intentionally built Long Island overpasses with really low clearances to ensure buses could never pass because he wanted to keep people of low income out of Long Island - because people of low income rely heavily on public transportation)
#
# When I manipulate the given code to represent this, it keeps running and not providing a solution.
# What I did was maintain the 2 classes for low and high income individuals (or people w cars and people w/out), decreased the population, set a minimum public transportation threshold to 2, and when the grid[x][y] == 0 that represents public transportation. I change the code in isHappy() to return if a person of low income (class #1) is surrounded by at least 2 forms of public transportation (class #0) then it is happy. If grid[x][y] = 0 or 2 then it is by default happy. Not sure why this doesnt work - let me know if you need any additional information or code. Thanks.
#
#
# 180
# So I change minNeighbors to minTransportation and made it 2 but I specifically changed isHappy() to mean that a low income person (of class 1) is happy if surrounded by at least 2 forms of transportation (which I am representing with a empty spot in the grid). My visualizer is now running after playing around with the parameters a bit, but its not showing the groupings I expected. Not sure how drastic of groupings you guys are looking for to prove our hypothesis, but still not sure how to change the parameter to make it represent what I want it to.
#
#
# 181
# Does Dijkstra's Algorithm produce a unique result?
#
#
# 182
# For some cases, I get NAN as output
# simulator = new SchellingSimulator(50, 2, 20, 2, 10, 10);
#
# What should I do?
#
#
# 183
# Can we assume that Node A and Node B are distinct?
#
#
# 184
# In CIS 121, we learned that the topological sort algorithm is
# 1) Run DFS
# 2) Return the nodes in reverse postorder (reverse order of the DFS finish times)
#
# Should we use this or the method from class which was
# 1) Remove the nodes and all their edges in order of increasing in-degree (ex. start with those with 0 incoming edges, etc.)
# ?
#
# I know both are conceptually the same, but since we are choosing nodes alphabetically, the result changes.
# For example, does that mean choose the nodes alphabetically while doing DFS? Or does it mean choose alphabetically when choosing which remaining node of minimum in-degree?
#
#
# 185
# I would also like to know the answer to this question.
# I took 121 and I did it the 121 way, which does return a different answer than the one taught in class. But both answers are topologically sorted. Is this okay?
#
#
# 186
# I guess it comes down to at which step do we choose the next alphabetical node?
#
#
# 187
# If there is no direct edge from node A to node B, but there is an intermediary node C that has edges to A and to B, does that count as an edge between A and B (in terms of strong triadic closure)?
#
#
# 188
# Do we need to justify why the graph is incorrect or correct?
#
#
# 189
# If we submitted a homework late, for up to 80% credit, would we be able to count extra credit points from other homeworks (ie homework 1) towards our score for the late one?
#
#
# 190
# Hi guys! My board gets populated, but not in the quantities that I want it to per class. I am trying the following modification to populate(), is there anything super obvious that I am missing?
#
# 	private void populate() {
# 		if (population &gt; width * height)
# 			throw new RuntimeException("Only " + width * height + " cells exist!");
#
# 		for (int i = 0; i &lt; population; i++) {
# 			int xChoice;
# 			int yChoice;
#
# 			int input = randGen.nextInt(classes) + 1;
# 			int c1 = 0;
# 			int c2 = 0;
# 			int c3 = 0;
#
# 			do {
# 				xChoice = randGen.nextInt(width);
# 				yChoice = randGen.nextInt(height);
# 			} while (grid[xChoice][yChoice] != 0);
#
# 			if(input == 1 &amp;&amp; c1 &lt;= Math.ceil(population*.48)){
# 			 grid[xChoice][yChoice] =  input;
# 			 c1++;
# 			} else if (input == 2 &amp;&amp; c2 &lt;= Math.ceil(population*.43)){
# 			 grid[xChoice][yChoice] =  input;
# 			 c2++;
# 			} else if (input == 3 &amp;&amp; c3 &lt;= Math.ceil(population*.09)){
# 			 grid[xChoice][yChoice] =  input;
# 			 c3++;
# 			} else {grid[xChoice][yChoice] = 0;}
#
# 		}
# 	}
#
#
#
# 191
# Can we just draw a graph where we get the incorrect shortest path or do we need to show why it gives us the wrong path?
#
#
# 192
# Is this ok?
#
#
# 193
# When I submitted, Canvas renamed my file from neilwei.zip to neilwei-1.zip (and then neilwei-2.zip when I resubmitted). Is this ok?
#
#
# 194
# Does the extra credit we got show up on Canvas?
#
#
# 195
# Including today's lecture?
#
#
# 196
# my code for HW 1 did not submit properly for some reason so i have an 8/100. i have sent my code in to the professor and resubmitted to the canvas site, but have received no further communication. I am just wondering what i can do?
#
#
# 197
# Where is the review being held tomorrow?
#
#
# 198
# Are the practice questions in the book helpful/approximation of what to expect?
#
#
# 199
# Are there answers to the questions in the book?
#
#
# 200
# I recall Professor Swapneel say in class that everything talked about in class is fair game and everything not talked about in class is not. Does that mean the required readings will not be tested on the exam?
#
#
# 201
# I was a little confused by the socket connection diagram that was explained at the beginning of Thursday's class.
# Why does a server need a port number when it has an IP address?
# How are the IP addresses allocated to the client and the server? I
# How do we choose which ports should be used to make the connection?
#
#
# 202
# Hello,
#
# I was invited to a superday for an investment fund I wanted to work for over my summer. However, the superday is on Thursday, and I won't be able to make it back in time for the midterm. Is it possible for me to reschedule the midterm? I can even take it later that day itself if that is most convenient, right after I come back from my interview. Can any accommodations be made?
#
#
# 203
# What is the difference between triadic, membership, and focal closure?
#
#
# 204
# The book mentions specific studies as examples, do we need to know these?
#
#
# 205
# Resolved
#
#
# 206
# Hi, I know we discussed this in class, but I can't find the email of the TA who graded me - who should I e-mail about a regrade? I don't think I got credit for the EC part of HW1! Thank you.
#
#
# 207
# Where is Active Learning?
#
#
# 208
# So basically it's just the length of the new shortest path?
#
#
# 209
# This is only the case with local bridges, correct? Would the span of a bridge (that is not local) be zero because deleting that bridge, by definition, causes the 2 nodes to be in separate components and there to be no path between the two?
#
#
# 210
# What is an affiliation network?
#
#
# 211
# Thanks! Are affiliation networks always bipartite?
#
#
# 212
# What's the difference? I haven't been able to find one.
#
#
# 213
# Could someone explain how DNS works? Or explain the example we did in class (cis.upenn.edu)? Thanks!
#
#
# 214
# Which of the lectures will cover the same material as that on the midterm? Here is the link I am talking about.
#
#
# 215
# Are HW solutions posted so we can review for exam?
#
# Thanks!
#
#
# 216
# When a device uses the DNS to map the human-readable form to an IP address what address is it mapping to? Isn't an IP address only assigned to a device?
#
#
# 217
# How do you recommend studying for the debugging section of the exam? What are some examples of types of bugs we might have to identify?
#
#
# 218
# Can someone post the file to piazza? Canvas seems to be down right now.
#
#
#
# 219
# Update, Piazza and Canvas are having some outages that prevent file upload.  The document will be posted once these have been resolved.
#
#
# 220
# Couldn't find more information on this.
#
# What is the logistic like for the midterm (room, open book?, cheatsheet? and format of exam).
#
# Thanks in advance!
#
#
# 221
# I missed class last week. Were any more details provided about the multiple choice and short answer sections?
#
#
# 222
# Which book chapters have we covered so far? 1-4?
#
#
#
# 223
# The review notes say that the DNS reads from left-to-right, but isn't it the other way around?
#
#
# 224
# What is the relation between bridges and triadic closures? In my notes, I have written something about Bridges and triadic closures being as counter or something? In addition, do bridges tell us anything about the degree of separation? And what exactly does degree of separation mean?
#
#
# 225
# The file is really weird/messed up on canvas. Can we get a fixed version?
#
#
# 226
# Is it important to read the textbook?
#
#
# 227
# Are there answers to the questions in the textbook?
#
#
# 228
# What exactly happens in these two layers? Do both of these layers send packets?
#
#
# 229
# So does the client and server code that we looked at occur in the Transport layer or the Application layer?
#
#
# 230
# I just wanted to check my answer to some of the questions in the textbook
# Section 3.7 (Chapter 3)
# Question 1: A little confused by what this question means by "explain how it plays a role in the formation of social networks". Would something like this be acceptable: The principle of triadic closure suggests social will form few bridges, because if a node B is a bridge between A and C, it is likely that A and C will themselves form an edge over time. Thus, because social networks will have few bridges, there will likely be more than one path between most pairs of nodes, which means it will tend to form into a "giant component".
# Question 2: B-C must be a weak tie, because by the strong triadic closure property, if B-C were a weak tie, then by the strong triadic closure property, there would be an edge between E and C, and clearly none exists.Question 3: All satisfy except C.
#
# Section 4.6 (Chapter 4)
#
# Question 1: There is most likely to be an edge between B and D, because they have the most number of mutual friends: A, C, and E. Thus, there are more opurtunities for A and E to interact, greater trust between them, and more of an incentive for their mutual friends to connect them to each other to reduce the lateral stress in their relationships, all by the principle of triadic closure.
#
#
# 231
# I have written down
#
#
#
# (V, E)
#
# Adjacency Matrix
#
# Adjacency List
#
# Space Required
#
# V2
#
# V+E
#
# Time
#
# 1
#
# V
#
# Find all neighbors of i
#
# V
#
# logV
#
#
#
# this table for the adjacency matrix and list, and when studying with a friend we realized that we have the times switched and the finding neighbors completely different. Could someone let me know what the actual right answers are for the time and neighbors portions of the table?
#
#
#
# 232
# Could you explain why we would need to iterate over all the neighbors and hence the time would be V? As I understand it, in an adjacency list, we can just return the list of neighbors indexed in an array. So if we're looking for all the neighbours of V_i, we can just return the list of neighbours indexed at i right?
#
#
# 233
# In the review session yesterday, I wrote in my notes that the clustering coefficient for a vertex is defined as: $$ C_A = \frac{deg(A)}{n-1} $$
#
# However, applying this formula to node $$A$$ in Figure 3.2(a) of the textbook doesn't give us the same result as explained in the text. The text says that $$C_A = \frac{1}{6}$$, but this formula yields $$\frac{4}{5}$$. Is there something I'm missing or is this formula applicable for a different scenario?
#
#
# 234
# Are there any good resources for reading about the link layer/transport layer, etc. other than lecture notes and midterm review material? I couldn't find it in the textbook. Also, can someone explain on a high level how the client server program we did in class is working in terms of the socket, server, port, etc.?
#
#
# 235
# What is an agglomerative method we looked at? I know we had the Girvan-Newman method as an example of a divisive approach
#
#
# 236
# I'm a little confused as to the purpose of a socket. Could someone explain that to me? I know we have port numbers designated to certain applications. How do sockets come in here?
#
#
# 237
# Do we need to know how to use the BFS method that appears on the book, or is it fine if we manually do it, as we saw in the lecture?
#
#
# 238
# Consider the following conjecture: In a directed graph G, if there is a path from node A to node B, then in any DFS on G, the start time of B must be less than or equal to the finish time of A. Is this true or false? If true, explain why. If false, show a counterexample.
#
# Was this true or false?
#
#
# 239
# Does someone mind providing a counterexample?
#
#
# 240
# Yes, that would be very useful...
#
#
# 241
# I missed the class where we went over Dijkstra's Algorithm because I was sick. When I look online there seem to be multiple ways to do it (as in create the chart). Does this video represent an acceptable way to show the algorithm? https://www.youtube.com/watch?v=8Ls1RqHCOPw
#
#
# 242
# For example, could a bug be that Client takes two constructors (servername and port number) but was only given one? Or will it be more about the actual function an logic of the classes?
#
#
#
# 243
# Could someone explain what complexity class NP and complexity class P are?
#
#
# 244
# Aren't problems in complexity class P also in complexity class NP? I thought that the definition of NP was that given a solution, the validity of the solution can be checked in poly-time.
#
#
# 245
# Will we need to know how to apply BFS/DFS to detect a cycle/prove a graph is bipartite etc?
#
#
# 246
# Can an instructor confirm? / Can the solution be posted?
#
#
# 247
# If a graph abides by strong triadic closure, is the following true?
#
# If the set of all of A's neighbors = the set of all of B's neighbors, then A and B share a strong tie
#
#
#
# 248
# The midterm notes say that if the neighborhood overlap of A and B is 1, then A and B share a strong tie. Why is this true? Additionally, if this is true, then is the above statement (in the original post) true?
#
#
# 249
# Is IP part of the internet layer?
#
#
# 250
#  If there are two paths that have the same cost, would Dijkstra's Algorithm pick the path that goes through less Nodes (or does it not matter/both ways are correct)?
#
#
# 251
# Just want to make sure I'm understanding homophily correctly - so in the way we learned in lecture where you have 2 classes, with p=fraction of nodes for class 1 and q=fraction of nodes for class 2, and the number of edges in the graph are y, then is it correct to say there exists homophily if 2*p*q*y &gt; the number of edges between class 1 and class 2 nodes
#
#
#
#
# 252
# Would it be possible to see the solutions for the theory part of HW II?
#
#
# 253
# ...
# It was the first time Salman's legal team heard details of the allegations. "We frankly expected more," attorney Linda Moreno said outside court.
# Salman's mother and uncle have pledged to put up their homes as collateral to secure her release from jail pending trial. Federal prosecutors are seeking to transfer Salman to Florida to face the charges that could bring a sentence of life in prison.
# Fox News' Claudia Cowan, Mike Lundin and the Associated Press contributed to this report.
#
# Reading file: file_2.txt and preprocessing
#
# documents contains: [query.txt, file_1.txt, file_2.txt]
# Creating the inverted index
# Creating the tf-idf weight vectors
#
# Comparing query.txt and file_1.txt
# NaN
#
# Comparing query.txt and file_2.txt
# NaN
#
# Comparing file_1.txt and file_2.txt
# NaN
#
# How can I get non-NaN cosine similarity values? I didn't have this issue in HW 4.
#
#
# 538
# Thank you so much! What was happening was that I created the Page object out of the file before closing the file. I now have cosine similarity values! Thank you so much!
#
#
# 539
# Is it ok if we import outside libraries to utilize certain algorithms?
#
#
# 540
# I have this question as well. I am currently using a CSV parser and was wondering if it was okay?
#
#
# 541
# Hello, I'm struggling to connect to the Twitter API due to all the OAuth and HTTP Requests that don't really exist in java. I was wondering what the best way to do this is - I am trying to collect all of Obama's and Trump's tweets. Thanks!
#
#
# 542
# nvm, I got it - Twitter4J
#
#
# 543
# Will there be a review session? If so, when and where? Thanks in advance!
#
#
# 544
# In the meantime, can you tell us the format of the exam as you did for the midterm?
#
#
# 545
# Any chance it's possible to record the review session?
#
#
# 546
# My team and I are using JSoup to collect the links from websites given a search query. The site lists articles and links underneath.
#
# Does anyone know how to parse through the "Load more" button so as to navigate to the rest of the search results?
#
#
# 547
# Hi, We want to visualize a very large network.
# In our hand we have a txt file of an edge list of 400,000 edges by 100,000 vertices.
#
# What kind of tools can we use to visualize this graph? Thank you!
#
#
# 548
# Are there any practice problems, practice exams, or previous exams to help with studying?  Or are there any recommendations on best ways to prepare?  Thanks!
#
#
# 549
# What's the average for hw3?
#
#
# 550
# it says 81.4 on my canvas
#
#
# 551
# If our data set is extremely large (&gt;1 GB), would it be alright to include a link to the data on SNAP in our report instead of including the entire dataset?
#
#
# 552
# When calculating betweenness in a weighted undirected graph, instead of 1 unit of flow being given is the value of flow just the weight on the edge?
#
#
# 553
# Is there any online description of the voting example we went over in class? (3 players, 2 rounds of votes)
# I couldn't find it in the textbook and I'm having some trouble understanding my notes.
#
#
# 554
# Thanks, I just read through the section about it in Strategies and Games. I think I understand the first part, but I don't get how we calculate the payoffs for the matrix before we do IEDS. What do the payoffs represent and are the players the voters?
#
#
# 555
# Our project is mainly doing something similar to HW3 and scraping Penn Course Review's data set then analyzing the data, however PCR is down and so are its corresponding APIs. This makes it impossible to get the data or even test our code. I've been talking with PennLabs and apparently they had some sort of issue upgrading the servers, it's been a few hours since then but it's still unresponsive. We're not sure what we should do at this point, we've emailed Professor Swap but he hasn't responded yet.
#
#
# 556
# Is it OK to submit summary report as a .pdf file, or does it need to be a .txt file?
#
#
# 557
# Submitting Final Project
#
# Do we have to submit all individually the same files?
# Or could one person submit the files as a representative.
#
#
# 558
# The graphs (up to 8748x4359 pixels) and logs (as many as 700 pages for one file) produced in my study were too large to comfortably fit into the report itself without occluding the main arguments, so I have included them in separate folders for my submission (the directory structure is explained in summary.txt) and referenced specific parts where appropriate - is this okay with the instructors?
#
#
# 559
# Hello,
# I got marked late for hw3, but I posted a while back that there was a mistake in my submission.
# Here is the post I made: @445
#
#
#
# The previous submission and the latest submission should not be different except for the writeup.
# Would it be possible for me to not have points deducted for lateness on hw3?
#
#
# 560
# Should we be prepared to expect words from both the final exam vocab list and the midterm list or just the final exam one?
#
#
# 561
# I received this comment on my output for Question 1 on the homework: "answer is Pixar, program outputs Disney"
#
# The question asks For the Best Animated Feature Category, which company has had the most nominations?
#
# Shouldn't the answer be DreamWorks Animation, since they have 11 nominations and the combination of Pixar and Disney only have 10 nominations? Also, my program outputs DreamWorks Animation.
#
#
# 562
# What's the difference between a web crawler and web indexer? I know a crawler, given a url, will follow links and explore all the pages, but what exactly does it do with that information? I know an indexer will assign unique IDs to a page and keeps track of incoming/outgoing links, but again, what does it do/how does it store this information?
#
#
# 563
# Does anyone know the difference between URIs and URNs? They're both identifiers, but I don't understand how they differ.
#
#
#
#
# 564
# Did we go over scaled pagerank in class? I remember we did Basic PageRank and Random Surfer Model, but I was reading through the Scaled Pagerank description in the textbook and I don't remember going through it. Do we need to know it?
#
#
# 565
# This is not covered in the textbook.
#
#
# 566
# Where do we see our extra credit scores on Canvas? My scores are not listed under the comment with the homework rubric, and the extra credit assignment scores are listed as 0/0 even though I completed extra credit for HW3 and HW4.
# Thank you!
#
#
# 567
# How is extra credit factored into our grade? Is it just another assignment? Or is it kind of like other CIS classes where the professor looks at how much extra credit you've done and manually decides you much your EC matters?
#
#
# 568
# Why is PageRank query independent? what exactly does query independent mean?
#
#
# 569
# How do you find the IEDS solution to this game?
#
#
# 570
# I see, so following this is the solution to the game DL?
#
#
# 571
# Do we know what the final exam format will be or what kind of questions we should expect?
#
#
# 572
# Does the final exam only cover contents from after the midterm, or does it cover everything?
#
#
# 573
# Are there any office hours scheduled for tomorrow?
#
#
# 574
# title
#
#
# 575
# title
#
#
# 576
# I have in my notes for the Random Surfer Model:
# X = a vector that models the probability distribution for current position
# $$X_o = (1, 0, 0, ...., 0)\\
# X_1 = X_0 * p \\
# X_n = X_{n-1} * P_n \\
# X_n = X_0 * P ^n \\
#  $$
#
# At time t, vector X converges, and $X_t$ holds the PageRank for all n pages.
# Can someone explain what this calculation is doing/means?
#
#
# 577
# if d is the probability of teleporting shouldn't the $$1-d$$ and $$d$$ terms be switched in this equation?
#
#
# 578
# Does anyone have the definition for strict best response and term(IR)? Also, is the only difference between a tdi matrix and boolean matrix that the tdi tells the amount of times the term occurs, whereas boolean just tells whether it occurs or not?
#
#
# 579
# Then whats the difference between strict best response and strictly dominant
#
#
# 580
# Can someone explain what the look-up times for seeing if two nodes are neighbors for an Adjacency Matrix vs List? I believe a matrix has time 1, and a list has time 1-V. Can someone explain why?
#
#
# 581
# What is the breakdown for this exam between programming, short answer, and vocab?
#
#
# 582
# So a first price auction is descending, while a second price auction is ascending? I'm a bit confused because the finals vocab list has first price sealed-bid and second price sealed-bid, and in this case, the prices aren't moving at all (hence they can't be ascending or descending)?
#
# Also, can you explain why second price auctions are ascending? I would think that first price auctions are equal to both descending and ascending auctions, where the winner pays their highest bid.
#
# I'm also a bit confused about why people use second price auctions - why not just have the winner pay the value of their bid (aka their true value for the object)?
#
#
# 583
# So are first price and second price auctions both games of incomplete information?
#
#
# 584
# The codes!!
#
#
# 585
# Is the "strongly dominant strategy" in the vocab list the same thing as a strictly dominant strategy?
#
#
# 586
# What does it mean for web search to have heterogenous quality and not homogenous?Also, what does it mean for web search to have no content control over curated control?
#
#
# 587
# Does Google Scholar (let's say, with advanced search options) fall under the classification of Web Search or Information Retrieval? How about ArXiv?
#
#
# 588
# http://stackoverflow.com/questions/176264/what-is-the-difference-between-a-uri-a-url-and-a-urn
#
# In the above link, what is the URL compared to the URI. I don't see any hash tags, so I'm unsure where the URL stops. Would URL and URI be the same. If so, does URL only every stop at a #?
#
#
# 589
# How much of the "Recommended Readings" in the syllabus such as tools.ietf.org/html/rfc3986 and suggested papers are fair game for the exam?
#
#
# 590
# Could someone confirm whether the required readings + homework covers all of the content covered in class (or if any, which topics were discussed in class but are not shown in the syllabus)?
#
#
# 591
# Do we have a practice final posted somewhere?
#
#
# 592
# Do we need to cover section 14.6 from Easley and Kleinberg for the exam?
#
#
# 593
# the book states -
# "Homophily Test: If the fraction of cross-gender edges is significantly less than 2pq, then there is evidence for homophily."
#
# Can someone explain what qualifies as significantly less?
#
#
# 594
# Can someone explain the correct answers to parts (b) and (c)? Thanks!
#
#
# 595
# And a) please?
#
#
# 596
# Are we allowed to contest these? I'd normally go to the OH of the TA who graded them, but I don't believe she has them today.
#
#
# 597
# What were the disadvantages of Basic PageRank?
#
#
# 598
# Thanks! So, how does the Random Surfer Model take care of this?
#
#
# 599
# In IEDS, can we eliminate weakly dominated strategies, or can we only eliminate strictly dominated strategies?
#
#
# 600
# in the textbook (page 199-200), I found an answer that is different from the above:
#
# "However, we can’t simply fix up the translation by eliminating weakly dominated strategies. We saw earlier that iterated deletion of strictly dominated strategies can be done in any order: all orders yield the same final result. But this is not true for the iterated deletion of weakly dominated strategies. To see this, suppose we vary the Market Entry Game slightly so that the payoff from the joint strategy (E, C) is (0, 0). (In this version, both firms know they will fail to gain a positive payoff even if Firm 2 cooperates on entry, although they still don’t do as badly as when Firm 2 retaliates.) R is a weakly dominated strategy as before, GAMES but now so is E. (E and S produce the same payoff for Firm 1 when Firm 2 chooses C, and S produces a strictly higher payoff when Firm 2 chooses R.)In this version of the game, there are now three (pure-strategy) Nash equilibria: (S, C), (E, C), and (S, R). If we first eliminate the weakly dominated strategy R, then we are left with (S, C) and (E, C) as equilibria. Alternately, if we first eliminate the weakly dominated strategy E, then we are left with (S, C) and (S, R) as equilibria. In both cases, no further elimination of weakly dominated strategies is possible, so the order of deletion affects the final set of equilibria. We can ask which of these equilibria actually make sense as predictions of play in this game. If this normal form actually arose from the dynamic version of the Market Entry Game, then C is still the only reasonable strategy for Firm 2, while Firm 1 could now play either S or E."
#
# two caveats -
# 1. the counterexample provided in chapter 6.10 refers to a dynamic game
# 2. elimination of weakly dominated strategies still finds a place in evolutionary games
#
#
# 601
# Are we allowed to bring a calculator to the exam? For example, could we use a calculator for any question that requires us to calculate the inverse document frequency?
#
# Thanks!
#
#
# 602
# Say the question was a adj list. Would drawing one answer the question? Or if it was clique, could I draw an example?
#
#
# 603
# The question is, "Suppose a user searches for “dobby elf”. Which is the best document that will be matched by the Vector Space model?" How would I go about doing this problem?
#
#
# 604
# Would you recompute the idf for each document and count the query as its own document?
#
#
# 605
# Can someone explain how the Random surfer model functions within the context of the basic pagerank rule?
#
#
# 606
# What are the correct solutions to these problems?
#
#
# 607
# How is it document B? I also got document A
#
#
# 608
# What is the correct solution to this problem?
#
#
# 609
# In a directed graph G, if there is a path from node A to node B, then in any DFS on G, the start time of B must be less than or equal to the finish time of A
#
#
# 610
# What are the exact definitions for sockets and ports? And what are their differences?
#
# Should our definitions be in the context of our Java code or more general?
#
#
# 611
# Will we be expected to know how to compute the cosine similarity between two documents? It was an extra credit question on a homework 4, so was unsure.
#
#
# 612
# sorry I am confused by this.  I thought weight was equal to tf * idf, why is this tf - idf?
#
#
#
# 613
# ^?
#
#
# 614
# Will we have to work through a graph and find the scaled PageRank of each page (rather than the basic PageRank)? If so, how do we go about doing this? I get confused after finding the matrix P and then figuring out what the vector x converges to
#
#
# 615
# What should we be expected to write on the exam, if asked?
#
#
# 616
# Anyway someone can post the right answer to this question? Got it wrong on the hw so unable to see correct answer. Thanks!!
#
#
# 617
# Are dutch auctions the same as descending bid auctions?
# Are english auctions the same as ascending bid auctions?
#
#
# 618
# what is this and what should we know about it other than that it is used in the Document Search code?
#
#
# 619
# did Professor Swap mention if there was going to be any debugging on the final as there was on the midterm? thanks
#
#
# 620
# Could questions be asked on hub and authority from Chapter 14 of the textbook?
#
#
# 621
# For the exam, will we need to know any formulas that are more complex than simple ratios? If so, are there any we should know that aren't already covered on the vocab list?
#
#
# 622
# Let's say we have a collection of documents. Next, we want to search them for some phrase, so we put the phrase in a new document and calculate the cosine similarity between the search document and all of the others, and then rank them from highest to lowest. However, as we added a new document, hypothetically our document frequency changes, so idf should as well. Do we update idf in this case for every term? Or, do we just leave it as is?
#
#
# 623
# I understand the concept but in terms of definition, is the wikipedia version good:
#
#
#
# A strategy consisting of possible moves and a probability distribution which corresponds to how frequently each move is to be played
#
#
#
#
#
#
#
# 624
# If we have already left campus there will be no way to view how our exams were graded?
#
#
# 625
# Is it possible to put the exams on gradescope? That way you don't have to necessarily keep the exams till the end of next semester, and we can have access to our exams over the break.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(raw_questions)

true_k = 750
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=10)
model.fit(X)

print("\n")
print("Prediction")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d9e7605d4e48> in <module>
#       8 true_k = 750
#       9 model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=10)
# ---> 10 model.fit(X)
#      11
#      12 print("\n")
#
# c:\users\gschw\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# c:\users\gschw\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     313     if _num_samples(X) < n_clusters:
#     314         raise ValueError("n_samples=%d should be >= n_clusters=%d" % (
# --> 315             _num_samples(X), n_clusters))
#     316
#     317     tol = _tolerance(X, tol)
#
# ValueError: n_samples=626 should be >= n_clusters=750

# %%
Y = vectorizer.transform(["Should we fail for empty queues for delete and contains too?"])
prediction = model.predict(Y)
print(prediction)

for x in range(5629):
    if model.labels_[x] == 158:
        print(raw_questions[x])
